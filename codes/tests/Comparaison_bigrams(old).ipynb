# %%
import numpy as np
import pandas as pd
import os
import re
from tqdm import tqdm
import ast
import scipy.cluster.hierarchy as shc
from scipy.spatial.distance import pdist, squareform
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /home/noe/python/miniconda/envs/coursnlp/lib/python3.7/site-packages (0.12.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /home/noe/python/miniconda/envs/coursnlp/lib/python3.7/site-packages (from seaborn) (3.5.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /home/noe/python/miniconda/envs/coursnlp/lib/python3.7/site-packages (from seaborn) (1.21.6)
# Requirement already satisfied: typing_extensions in /home/noe/python/miniconda/envs/coursnlp/lib/python3.7/site-packages (from seaborn) (4.5.0)
# Requirement already satisfied: pandas>=0.25 in /home/noe/python/miniconda/envs/coursnlp/lib/python3.7/site-packages (from seaborn) (1.3.5)
# Requirement already satisfied: pillow>=6.2.0 in /home/noe/python/miniconda/envs/coursnlp/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/noe/python/miniconda/envs/coursnlp/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/noe/python/miniconda/envs/coursnlp/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /home/noe/python/miniconda/envs/coursnlp/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: packaging>=20.0 in /home/noe/python/miniconda/envs/coursnlp/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/noe/python/miniconda/envs/coursnlp/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/noe/python/miniconda/envs/coursnlp/lib/python3.7/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: pytz>=2017.3 in /home/noe/python/miniconda/envs/coursnlp/lib/python3.7/site-packages (from pandas>=0.25->seaborn) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /home/noe/python/miniconda/envs/coursnlp/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)

# %%
import sys
sys.version
# Out:
# '3.7.16 (default, Jan 17 2023, 22:20:44) \n[GCC 11.2.0]'

# %% [markdown]
# # Fonctions

# %%
def clean_text(text):
    
    text2 = re.sub('!','.',text)
    text2 = re.sub(' \...',' ',text)
    text2 = re.sub('  ',' ',text2)
    char  = [';',':','!','«','»',',','“','”','(',')']
    pattern = '[' + ''.join(char) + ']'
    new_str = re.sub(pattern,'', text2)
    #clean_words = [word for word in new_str.split() if word.lower() not in stopwords_latin]
    #new_str = ' '.join(clean_words)
    new_str = re.sub(r'\? [A-Z]','.',new_str)
    new_str = re.sub(r'\?','',new_str)
    pattern = r"\. ([a-z])"
    new_str = re.sub(pattern, r" \1", new_str)
    string = new_str.split('.')
    string = [x for x in string if x != '']
    string = [x for x in string if x != ' ']
    string = [x.lower() for x in string]
    string = [x.lstrip() for x in string]
    string = [x.rstrip() for x in string]
    string = [re.sub('v','u',x) for x in string]
    string = [re.sub('j','i',x) for x in string]
    
    return string

# %%
def clean_text_stopwords(text):
    
    text2 = re.sub('!','.',text)
    text2 = re.sub(' \...',' ',text)
    text2 = re.sub('  ',' ',text2)
    char  = [';',':','!','«','»',',','“','”']
    pattern = '[' + ''.join(char) + ']'
    new_str = re.sub(pattern,'', text2)
    clean_words = [word for word in new_str.split() if word.lower() not in stopwords_latin]
    new_str = ' '.join(clean_words)
    new_str = re.sub(r'\? [A-Z]','.',new_str)
    new_str = re.sub(r'\?','',new_str)
    pattern = r"\. ([a-z])"
    new_str = re.sub(pattern, r" \1", new_str)
    string = new_str.split('.')
    string = [x for x in string if x != '']
    string = [x for x in string if x != ' ']
    string = [x.lower() for x in string]
    string = [x.lstrip() for x in string]
    string = [x.rstrip() for x in string]
    string = [re.sub('v','u',x) for x in string]
    string = [re.sub('j','i',x) for x in string]
    
    return string

# %%
def remove_words(sentence, words_to_remove):
    for word in words_to_remove:
        sentence = re.sub(r'\b{}\b'.format(word), '', sentence)
        sentence = re.sub("  "," ",sentence)
    return sentence.strip()

# %%
def compare_sentences(sentence_1, sentence_2):
    words_1 = sentence_1.lower().split()
    words_2 = sentence_2.lower().split()

    common_words = set(words_1) & set(words_2)

    return len(common_words) >= 2

# %%
def distance_index(text, word1, word2, max_distance=10):
    words = text.split()
    index1 = None
    index2 = None

    for i, word in enumerate(words):
        if word == word1:
            index1 = i
        elif word == word2:
            index2 = i

    if index1 is not None and index2 is not None:
        distance = abs(index2 - index1)
        if distance <= max_distance:
            return True
        else:
            return False
    else:
        return False

# %%
def create_bigrams(sentence):
    words = sentence.split()
    bigrams = [(words[i], words[i+1]) for i in range(len(words) - 1)]
    return bigrams

# %%
def substitute_keys(dict1, dict2):
    result_dict = {}

    for key1 in dict1.keys():
        
        for value2 in dict2.values():
           
            if value2 == key1:
                
                for key2, value2_2 in dict2.items():
                    if value2_2 == value2:

                        result_dict[key2] = dict1[key1]
                        break  

    return result_dict

# %%
def transform_sentences_to_keys(dict1, dict2):
    # Create a new dictionary to store the result
    result_dict = {}

    # Iterate through the keys and sentences in dict1
    for key1, sentences_list1 in dict1.items():
        # Initialize a list to store matching keys from dict2
        keys_list = []
        for sentence1 in sentences_list1:
            # Find the matching key from dict2 for the current sentence1
            for key2, sentence2 in dict2.items():
                if sentence1 == sentence2:
                    keys_list.append(key2)

        # Add the list of keys corresponding to sentences in dict1 to the result_dict
        result_dict[key1] = keys_list

    return result_dict

# %%
def from_bigrams_to_sentence(bigram): 

    test = []

    i = 0

    while i <= len(bigram)-1:
        test.append(bigram[i][0])
        i += 1
        
    test.append(bigram[-1][-2])
    test.append(bigram[-1][-1])

    final  = " ".join(test)
    
    return final

# %%
matches = {}

def comparaison_bi_grams(bigram):   
    #bigram = pdv_bigrams[0]

    liste_vide = []

    for i in bigram:

        for test in guerin_bigrams:

            if i in test:
                liste_vide.append(from_bigrams_to_sentence(test))
                matches[from_bigrams_to_sentence(bigram)] = liste_vide

# %%
def create_trigrams(sentence):
    words = sentence.split()
    trigrams = [(words[i], words[i+1], words[i+2]) for i in range(len(words) - 2)]
    return trigrams

# %%
def from_trigrams_to_sentence(trigram): 

    test = []

    i = 0

    while i <= len(trigram)-1:
        test.append(trigram[i][0])
        i += 1
    test.append(trigram[-1][-2])
    test.append(trigram[-1][-1])

    final  = " ".join(test)
    
    return final

# %%
matches_trigrams = {}

def comparaison_trigrams(trigram):   
    #bigram = pdv_bigrams[0]

    liste_vide = []

    for i in trigram:

        for test in guerin_trigrams:

            if i in test:
                liste_vide.append(from_trigrams_to_sentence(test))
                matches_trigrams[from_trigrams_to_sentence(trigram)] = liste_vide

# %%
def remove_duplicates_from_dict_values(dictionary):
    for key, value_list in dictionary.items():
        # Convert the value list to a set to remove duplicates, then back to a list
        dictionary[key] = list(set(value_list))
    return dictionary

# %%
def create_quadrigrams(sentence):
    words = sentence.split()
    quadrigrams = [(words[i], words[i+1], words[i+2], words[i+3]) for i in range(len(words) - 3)]
    return quadrigrams

# %%
def from_quadrigrams_to_sentence(quadrigram): 

    test = []

    i = 0

    while i <= len(quadrigram)-1:
        test.append(quadrigram[i][0])
        i += 1
    
    test.append(quadrigram[-1][-3])
    test.append(quadrigram[-1][-2])
    test.append(quadrigram[-1][-1])

    final  = " ".join(test)
    
    return final

# %%
matches_quadrigrams = {}

def comparaison_quadrigrams(quadrigram):   
    #bigram = pdv_bigrams[0]

    liste_vide = []

    for i in quadrigram:

        for test in guerin_quadrigrams:

            if i in test:
                liste_vide.append(from_quadrigrams_to_sentence(test))
                matches_quadrigrams[from_quadrigrams_to_sentence(quadrigram)] = liste_vide

# %%
def create_quintigrams(sentence):
    words = sentence.split()
    quintigrams = [(words[i], words[i+1], words[i+2], words[i+3], words[i+4]) for i in range(len(words) - 4)]
    return quintigrams

# %%
def from_quintigrams_to_sentence(quintigram): 

    test = []

    i = 0

    while i <= len(quintigram)-1:
        test.append(quintigram[i][0])
        i += 1
    
    test.append(quintigram[-1][-4])
    test.append(quintigram[-1][-3])
    test.append(quintigram[-1][-2])
    test.append(quintigram[-1][-1])

    final  = " ".join(test)
    
    return final

# %%
matches_quintigrams = {}

def comparaison_quintigrams(quintigram):   
    #bigram = pdv_bigrams[0]

    liste_vide = []

    for i in quintigram:

        for test in guerin_quintigrams:

            if i in test:
                liste_vide.append(from_quintigrams_to_sentence(test))
                matches_quintigrams[from_quintigrams_to_sentence(quintigram)] = liste_vide

# %%
def delete_empty_values(dictionary):
    keys_to_delete = []
    for key, value in dictionary.items():
        if not value:
            keys_to_delete.append(key)
    for key in keys_to_delete:
        dictionary.pop(key)
def remove_character_from_values(dictionary, character):
    for key, value in dictionary.items():
        if isinstance(value, str):
            dictionary[key] = value.replace(character, '')

# %% [markdown]
# # Préparation des dictionnaires avec les indices et les phrases de chaque corpus

# %%
file = '/home/noe/Documents/2022-2023/ENC/Mémoire/Dataframes/PDV_grams.xlsx'
guerin = '/home/noe/Documents/2022-2023/ENC/Mémoire/Dataframes/Guerin_grams.xlsx'

# %%
os.chdir('/home/noe/Documents/2022-2023/ENC/Mémoire/Comparaison_de_mots/')

# %%
df_PDV = pd.read_excel(file)

# %%
stopwords_latin = ['©','quod','et','a', 'ab', 'ac', 'ad', 'adhic', 'aliqua', 'aliquae', 'aliquam', 'aliqui', 'aliquis', 'an', 'ante', 'apud', 'at', 'atque', 'aut', 'autem', 'cetera', 'ceterae', 'ceteri', 'ceteris', 'cetero', 'ceterorum', 'ceteros', 'ceterum', 'ceterus', 'cum', 'cur', 'de', 'deinde', 'dum', 'ea', 'eae', 'eam', 'earum', 'eas', 'eis', 'eo', 'eorum', 'eos', 'eum', 'eundem', 'eumdem', 'ex', 'fio', 'haec', 'hanc', 'hic', 'hoc', 'huc', 'iam', 'idem', 'igitur', 'ii', 'iis', 'ille', 'illius', 'in', 'infra', 'inter', 'interim', 'ipse', 'ipsa', 'ipsam', 'ipsis', 'ipsius', 'ipsorum', 'ipsos', 'ita', 'magis', 'modo', 'mox', 'nam', 'ne', 'nec', 'necne', 'necque', 'neque', 'nisi', 'non', 'nos', 'nostra', 'nostrae', 'nostram', 'nostri', 'nostris', 'notre', 'o', 'ob', 'per', 'possum', 'post', 'pro', 'quae', 'quam', 'quare', 'qui', 'quia', 'quibus', 'quid', 'quidem', 'quin', 'quis', 'quisnam', 'quisquam', 'quisque', 'quo', 'quoniam', 'sed', 'si', 'sibi', 'sic', 'sicut', 'sine', 'sive', 'sub', 'sua', 'suam', 'sui', 'suis', 'sum', 'super', 'supra', 'suus', 'tam', 'tamen', 'trans', 'tu', 'tua', 'tunc', 'tuo', 'tuos', 'tuus', 'ubi', 'uel', 'uelut', 'uero', 'unus', 'ut']

# Ajout des déterminants de la liste précédente
stopwords_latin += ['mei', 'tui', 'sui', 'nostri', 'vestri', 'suus', 'meus', 'tuus', 'noster', 'vester', 'eius', 'eae', 'ea', 'eum', 'eam', 'eos', 'eas', 'id', 'is', 'illa', 'illud', 'illi', 'illis', 'ipsum', 'ipsam', 'ipsa', 'ipsi', 'ipsis', 'idem', 'eadem', 'idemque', 'eademque']

# %%
df = pd.DataFrame({'texts':df_PDV['textes'],'clean_PDV': df_PDV['textes'].apply(clean_text)})

# %%
df_guerin = pd.read_excel(guerin)

# %%
pdv = {}
for i in range(len(df)):
    for sentence in df['clean_PDV'][i]:
        pdv[ f'pdv_{i+1}_{df["clean_PDV"][i].index(sentence)+1}'] = sentence

# %%
df2 = pd.DataFrame({'guerin_texts':df_guerin['text'],'clean_guerin':df_guerin['text'].apply(clean_text),
                   'guerin_stop': df_guerin['text'].apply(clean_text_stopwords)})

# %%
column_without_brackets = [[string.replace('[', '').replace(']', '').lstrip().rstrip() for string in sublist] for sublist in df2['clean_guerin']]

# %%
df2['clean'] = column_without_brackets

# %%
guerin = {}
for i in range(len(df2)):
    for sentence in df2['clean'][i]:        
        guerin[f'guerin_{i+1}_{df2["clean"][i].index(sentence)+1}'] = sentence

# %%
viard = '/home/noe/Documents/2022-2023/ENC/Mémoire/Dataframes/Viard_grams.xlsx'
df_viard = pd.read_excel(viard)

# %%
df3 = pd.DataFrame({'clean_viard':df_viard['text'].apply(clean_text)})

# %%
viard = {}

for i in range(len(df3)):
    for sentence in df3['clean_viard'][i]:
        viard[f'viard_{i+1}_{df3["clean_viard"][i].index(sentence)+1}'] = sentence

# %%
pdv_2 = {key: remove_words(value,stopwords_latin) for key, value in pdv.items()}
guerin_2 = {key: remove_words(value,stopwords_latin) for key, value in guerin.items()}

# %%
remove_character_from_values(pdv,'©')
remove_character_from_values(pdv,'|')
delete_empty_values(pdv)

# %%
remove_character_from_values(guerin_2,'©')
remove_character_from_values(guerin_2,'|')
delete_empty_values(guerin_2)

# %%
x = list(pdv.values())

# %%
y = list(guerin_2.values())

# %%
from typing import List
from pie_extended.cli.utils import get_tagger, get_model, download

# In case you need to download
do_download = False
if do_download:
    for dl in download("lasla"):
        x = 1

# model_path allows you to override the model loaded by another .tar
model_name = "lasla"
tagger = get_tagger(model_name, batch_size=256, device="cpu", model_path=None)

liste_dic_guerin = []
for i in tqdm(range(len(y))):
    sentences: List[str] = [y[i]]
    # Get the main object from the model (: data iterator + postprocesor
    from pie_extended.models.lasla.imports import get_iterator_and_processor
    for sentence_group in sentences:
        iterator, processor = get_iterator_and_processor()
        dic = tagger.tag_str(sentence_group, iterator=iterator, processor=processor)
        liste_dic_guerin.append(dic)
# Out:
# 100%|███████████████████████████████████████| 4041/4041 [11:25<00:00,  5.89it/s]

# %%
from typing import List
from pie_extended.cli.utils import get_tagger, get_model, download

# In case you need to download
do_download = False
if do_download:
    for dl in download("lasla"):
        x = 1

# model_path allows you to override the model loaded by another .tar
model_name = "lasla"
tagger = get_tagger(model_name, batch_size=256, device="cpu", model_path=None)

liste_dic2 = []
for i in tqdm(range(len(x))):
    sentences: List[str] = [x[i]]
    # Get the main object from the model (: data iterator + postprocesor
    from pie_extended.models.lasla.imports import get_iterator_and_processor
    for sentence_group in sentences:
        iterator, processor = get_iterator_and_processor()
        dic = tagger.tag_str(sentence_group, iterator=iterator, processor=processor)
        liste_dic2.append(dic)
# Out:
#  65%|█████████████████████████▌             | 1356/2071 [04:56<02:53,  4.12it/s]

# %%
len(liste_dic2)
# Out:
# ('pdv_363_1',
#  'notum facimus uniuersitati uestrae fidelis iuxta sacrarum constitutionem nostrarum tenorem examinatus inuentus fidelis genere fidelium ortus sufficiens notariatus officium excercendum est curiam approbatus')

# %%
liste_finale_guerin = []

for i in tqdm(liste_dic_guerin):
    liste_sentence = []
    for j in i:
        liste_sentence.append(j.get('lemma'))
    liste_finale_guerin.append(liste_sentence)
# Out:
# 100%|███████████████████████████████████| 4041/4041 [00:00<00:00, 144161.25it/s]

# %%
liste_finale = []

for i in tqdm(liste_dic):
    liste_sentence = []
    for j in i:
        liste_sentence.append(j.get('lemma'))
    liste_finale.append(liste_sentence)
# Out:
# 100%|███████████████████████████████████| 2048/2048 [00:00<00:00, 174153.24it/s]

# %%
liste_finale = [' '.join(sublist) for sublist in liste_finale]
liste_finale_guerin = [' '.join(sublist) for sublist in liste_finale_guerin]

# %%
pdv_lemma = {key: value for key, value in zip(list(pdv_2.keys()), liste_finale)}
guerin_lemma = {key: value for key, value in zip(list(guerin_2.keys()), liste_finale_guerin)}

# %% [markdown]
# # Méthode deux pour les correspondances de bi-tr-quadri-quinti grams

# %%
complete_list = []
match_bi = {}

for i in tqdm(list(pdv_lemma.keys())):
    big = create_bigrams(pdv_lemma.get(i))
    correspondance = []
    lesgrams = []

    for key in list(guerin_lemma.keys()):
        liste_bigrams = create_bigrams(guerin_lemma.get(key))
        for bigram in big:
            if bigram in liste_bigrams:
                correspondance.append(key)
                lesgrams.append(bigram)
                break
                
    match_bi[i] = correspondance
delete_empty_values(match_bi)

count_match = {}

for key, value in match_bi.items():
    count_match[key] = len(value)

count_sentences_match = {}
#nombre de phrases qui ont au moins un bigramme similaire avec une phrase de guérin. 

for i in tqdm(range(363)):
    filtered_dict = {key: value for key, value in count_match.items() if key.startswith(f"pdv_{i+1}_")}
    count_sentences_match[f'pdv_{i+1}'] = sum(filtered_dict.values())

keys = list(count_sentences_match.keys())
values = list(count_sentences_match.values())

livre_1 = {}
livre_2 = {}
livre_3 = {}
livre_4 = {}
livre_5 = {}
livre_6 = {}

for i in range(len(keys)):
    if i < 33:
        livre_1[keys[i]] = values[i]
    if 32 < i < 92:
        livre_2[keys[i]] = values[i]
    if 91 < i < 179:
        livre_3[keys[i]] = values[i]
    if 178 < i < 195:
        livre_4[keys[i]] = values[i]
    if 194 < i < 331:
        livre_5[keys[i]] = values[i]
    if 330 < i < 364:
        livre_6[keys[i]] = values[i]
        
one = list(livre_1.values())
two = list(livre_2.values())
three = list(livre_3.values())
four = list(livre_4.values())
five = list(livre_5.values())
six = list(livre_6.values())
liste_livres = [one, two, three, four, five, six]

sns.set(style="whitegrid")
facecolor = '#eaeaf2'
fig, ax = plt.subplots(figsize=(12, 9), facecolor=facecolor)
sns.boxplot(data=liste_livres, palette="Set3",showmeans=True,
            meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
plt.yscale("log")
ax.set_ylabel('Nombres de correspondances de bigrams de mots dans les textes de Guérin', 
              fontsize=12)
custom_labels = ['livre 1','livre 2','livre 3','livre 4','livre 5','livre 6']
plt.xticks(range(len(custom_labels)), custom_labels)
plt.title('Nombre de phrases de Guérin dans lesquelles on retrouve au moins un bigram en commun avec Pierre de la Vigne')

liste_bigrams = [sum(livre_1.values()),sum(livre_2.values()),sum(livre_3.values()),
                     sum(livre_4.values()),sum(livre_5.values()),sum(livre_6.values())]
# Out:
# 100%|███████████████████████████████████████| 2048/2048 [02:24<00:00, 14.18it/s]
# 100%|███████████████████████████████████████| 363/363 [00:00<00:00, 3275.02it/s]
# 33
# 136
# [225, 399, 386, 52, 457, 440, 246, 564, 942, 32, 575, 345, 568, 71, 4, 314, 401, 73, 616, 125, 353, 236, 457, 406, 482, 636, 1, 2, 473, 0, 1, 389]
# [366, 202, 795, 131, 181, 126, 181, 332, 73, 178, 120, 132, 49, 58, 152, 128, 156, 99, 247, 9, 1181, 63, 29, 144, 12, 235, 263, 299, 139, 260, 6, 8, 157]
# Text(0.5, 1.0, 'Nombre de phrases de Guérin dans lesquelles on retrouve au moins un bigram en commun avec Pierre de la Vigne')

# %%
liste_bigrams = [sum(livre_1.values()),sum(livre_2.values()),sum(livre_3.values()),
                     sum(livre_4.values()),sum(livre_5.values()),sum(livre_6.values())]

# %%
complete_list_tri = []
match_tri = {}

for i in tqdm(list(pdv_lemma.keys())):
    big = create_trigrams(pdv_lemma.get(i))
    correspondance = []
    lesgrams = []

    for key in list(guerin_lemma.keys()):
        liste_trigrams = create_trigrams(guerin_lemma.get(key))
        for trigram in big:
            if trigram in liste_trigrams:
                correspondance.append(key)
                lesgrams.append(trigram)
                break
                
    match_tri[i] = correspondance
delete_empty_values(match_tri)

count_match_tri = {}

for key, value in match_tri.items():
    count_match_tri[key] = len(value)

count_sentences_match_tri = {}
#nombre de phrases qui ont au moins un bigramme similaire avec une phrase de guérin. 

for i in tqdm(range(363)):
    filtered_dict = {key: value for key, value in count_match_tri.items() if key.startswith(f"pdv_{i+1}_")}
    count_sentences_match_tri[f'pdv_{i+1}'] = sum(filtered_dict.values())

keys = list(count_sentences_match_tri.keys())
values = list(count_sentences_match_tri.values())

livre_1 = {}
livre_2 = {}
livre_3 = {}
livre_4 = {}
livre_5 = {}
livre_6 = {}

for i in range(len(keys)):
    if i < 33:
        livre_1[keys[i]] = values[i]
    if 32 < i < 92:
        livre_2[keys[i]] = values[i]
    if 91 < i < 179:
        livre_3[keys[i]] = values[i]
    if 178 < i < 195:
        livre_4[keys[i]] = values[i]
    if 194 < i < 331:
        livre_5[keys[i]] = values[i]
    if 330 < i < 364:
        livre_6[keys[i]] = values[i]
        
one = list(livre_1.values())
two = list(livre_2.values())
three = list(livre_3.values())
four = list(livre_4.values())
five = list(livre_5.values())
six = list(livre_6.values())
liste_livres = [one, two, three, four, five, six]

sns.set(style="whitegrid")
facecolor = '#eaeaf2'
fig, ax = plt.subplots(figsize=(12, 9), facecolor=facecolor)
sns.boxplot(data=liste_livres, palette="Set3",showmeans=True,
            meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
plt.yscale("log")
ax.set_ylabel('Nombres de correspondances de bigrams de mots dans les textes de Guérin', 
              fontsize=12)
custom_labels = ['livre 1','livre 2','livre 3','livre 4','livre 5','livre 6']
plt.xticks(range(len(custom_labels)), custom_labels)
plt.title('Nombre de phrases de Guérin dans lesquelles on retrouve au moins un bigram en commun avec Pierre de la Vigne')


liste_trigrams = [sum(livre_1.values()),sum(livre_2.values()),sum(livre_3.values()),
                     sum(livre_4.values()),sum(livre_5.values()),sum(livre_6.values())]
# Out:
# 100%|███████████████████████████████████████| 2048/2048 [02:21<00:00, 14.44it/s]
# 100%|██████████████████████████████████████| 363/363 [00:00<00:00, 29029.37it/s]

# %%
liste_trigrams
# Out:
# [61, 67, 95, 5, 242, 2110]

# %%
complete_list_quadri = []
match_quadri = {}

for i in tqdm(list(pdv_lemma.keys())):
    big = create_quadrigrams(pdv_lemma.get(i))
    correspondance = []
    lesgrams = []

    for key in list(guerin_lemma.keys()):
        liste_quadrigrams = create_quadrigrams(guerin_lemma.get(key))
        for quadri in big:
            if quadri in liste_quadrigrams:
                correspondance.append(key)
                lesgrams.append(quadri)
                break
                
    match_quadri[i] = correspondance
delete_empty_values(match_quadri)

count_match_quadri = {}

for key, value in match_quadri.items():
    count_match_quadri[key] = len(value)

count_sentences_match_quadri = {}
#nombre de phrases qui ont au moins un bigramme similaire avec une phrase de guérin. 

for i in tqdm(range(363)):
    filtered_dict = {key: value for key, value in count_match_quadri.items() if key.startswith(f"pdv_{i+1}_")}
    count_sentences_match_quadri[f'pdv_{i+1}'] = sum(filtered_dict.values())

keys = list(count_sentences_match_quadri.keys())
values = list(count_sentences_match_quadri.values())

livre_1 = {}
livre_2 = {}
livre_3 = {}
livre_4 = {}
livre_5 = {}
livre_6 = {}

for i in range(len(keys)):
    if i < 33:
        livre_1[keys[i]] = values[i]
    if 32 < i < 92:
        livre_2[keys[i]] = values[i]
    if 91 < i < 179:
        livre_3[keys[i]] = values[i]
    if 178 < i < 195:
        livre_4[keys[i]] = values[i]
    if 194 < i < 331:
        livre_5[keys[i]] = values[i]
    if 330 < i < 364:
        livre_6[keys[i]] = values[i]
        
one = list(livre_1.values())
two = list(livre_2.values())
three = list(livre_3.values())
four = list(livre_4.values())
five = list(livre_5.values())
six = list(livre_6.values())
liste_livres = [one, two, three, four, five, six]

sns.set(style="whitegrid")
facecolor = '#eaeaf2'
fig, ax = plt.subplots(figsize=(12, 9), facecolor=facecolor)
sns.boxplot(data=liste_livres, palette="Set3",showmeans=True,
            meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
plt.yscale("log")
ax.set_ylabel('Nombres de correspondances de bigrams de mots dans les textes de Guérin', 
              fontsize=12)
custom_labels = ['livre 1','livre 2','livre 3','livre 4','livre 5','livre 6']
plt.xticks(range(len(custom_labels)), custom_labels)
plt.title('Nombre de phrases de Guérin dans lesquelles on retrouve au moins un bigram en commun avec Pierre de la Vigne')


liste_quadrigrams = [sum(livre_1.values()),sum(livre_2.values()),sum(livre_3.values()),
                     sum(livre_4.values()),sum(livre_5.values()),sum(livre_6.values())]
# Out:
# 100%|███████████████████████████████████████| 2048/2048 [02:16<00:00, 15.04it/s]
# 100%|█████████████████████████████████████| 363/363 [00:00<00:00, 207740.80it/s]

# %%
complete_list_quinti = []
match_quinti = {}

for i in tqdm(list(pdv_lemma.keys())):
    big = create_quintigrams(pdv_lemma.get(i))
    correspondance = []
    lesgrams = []

    for key in list(guerin_lemma.keys()):
        liste_quintigrams = create_quintigrams(guerin_lemma.get(key))
        for quinti in big:
            if quinti in liste_quintigrams:
                correspondance.append(key)
                lesgrams.append(quinti)
                break
                
    match_quinti[i] = correspondance
delete_empty_values(match_quinti)

count_match_quinti = {}

for key, value in match_quinti.items():
    count_match_quinti[key] = len(value)

count_sentences_match_quinti = {}
#nombre de phrases qui ont au moins un bigramme similaire avec une phrase de guérin. 

for i in tqdm(range(363)):
    filtered_dict = {key: value for key, value in count_match_quinti.items() if key.startswith(f"pdv_{i+1}_")}
    count_sentences_match_quinti[f'pdv_{i+1}'] = sum(filtered_dict.values())

keys = list(count_sentences_match_quinti.keys())
values = list(count_sentences_match_quinti.values())

livre_1 = {}
livre_2 = {}
livre_3 = {}
livre_4 = {}
livre_5 = {}
livre_6 = {}

for i in range(len(keys)):
    if i < 33:
        livre_1[keys[i]] = values[i]
    if 32 < i < 92:
        livre_2[keys[i]] = values[i]
    if 91 < i < 179:
        livre_3[keys[i]] = values[i]
    if 178 < i < 195:
        livre_4[keys[i]] = values[i]
    if 194 < i < 331:
        livre_5[keys[i]] = values[i]
    if 330 < i < 364:
        livre_6[keys[i]] = values[i]
        
one = list(livre_1.values())
two = list(livre_2.values())
three = list(livre_3.values())
four = list(livre_4.values())
five = list(livre_5.values())
six = list(livre_6.values())
liste_livres = [one, two, three, four, five, six]
"""
sns.set(style="whitegrid")
facecolor = '#eaeaf2'
fig, ax = plt.subplots(figsize=(12, 9), facecolor=facecolor)
sns.boxplot(data=liste_livres, palette="Set3",showmeans=True,
            meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
plt.yscale("log")
ax.set_ylabel('Nombres de correspondances de bigrams de mots dans les textes de Guérin', 
              fontsize=12)
custom_labels = ['livre 1','livre 2','livre 3','livre 4','livre 5','livre 6']
plt.xticks(range(len(custom_labels)), custom_labels)
plt.title('Nombre de phrases de Guérin dans lesquelles on retrouve au moins un bigram en commun avec Pierre de la Vigne')"""


liste_quintigrams = [sum(livre_1.values()),sum(livre_2.values()),sum(livre_3.values()),
                     sum(livre_4.values()),sum(livre_5.values()),sum(livre_6.values())]
# Out:
# 100%|███████████████████████████████████████| 2048/2048 [02:15<00:00, 15.15it/s]
# 100%|█████████████████████████████████████| 363/363 [00:00<00:00, 545515.00it/s]

# %%
data = [liste_bigrams,liste_trigrams,liste_quadrigrams,liste_quintigrams]

columns = ('livre 1', 'livre 2', 'livre 3', 'livre 4', 'livre 5', 'livre 6')

# %%
sns.set(style="whitegrid")
facecolor = '#eaeaf2'
data = data

columns = ('livre 1', 'livre 2', 'livre 3', 'livre 4', 'livre 5', 'livre 6')
rows = [x for x in ('quinti-grams', 'quadri-grams', 'tri-grams', 'bi-grams')
]

plt.figure(figsize=(15,9))

values = np.arange(0, 10001, 2000)
value_increment = 2000

# Get some pastel shades for the colors
colors = plt.cm.tab20c(np.linspace(0, 1, len(rows)))
n_rows = len(data)

index = np.arange(len(columns)) + 0.3
bar_width = 0.4

# Initialize the vertical-offset for the stacked bar chart.
y_offset = np.zeros(len(columns))

# Plot bars and create text labels for the table
cell_text = []
for row in range(n_rows):
    plt.bar(index, data[row], bar_width, bottom=y_offset, color=colors[row])
    y_offset = y_offset + data[row]
    cell_text.append(['%d' % x for x in data[row]])

# Reverse colors and text labels to display the last value at the top.
colors = colors[::-1]
cell_text.reverse()

# Add a table at the bottom of the axes
the_table = plt.table(cellText=cell_text,
                      rowLabels=rows,
                      rowColours=colors,
                      colLabels=columns,
                      loc='bottom')

# Adjust layout to make room for the table:
plt.subplots_adjust(left=0.2, bottom=0.2)

plt.ylabel(f"Loss in ${value_increment}'s")

plt.yticks(values, ['%d' % val for val in values])
plt.xticks([])
plt.title('A')


plt.show()

# %%
data
# Out:
# [[6511, 5862, 8900, 1224, 14941, 10271],
#  [61, 67, 95, 5, 242, 2110],
#  [0, 4, 6, 0, 21, 1130],
#  [0, 0, 0, 0, 0, 514]]

# %%
[[6330, 5862, 8332, 1224, 14920, 10271],
 [58, 67, 85, 5, 242, 2110],
 [0, 4, 6, 0, 21, 1130],
 [0, 0, 0, 0, 0, 514]]

# %% [markdown]
# # Bigrams de lemmes

# %%
guerin_bigrams = []

for i in list(guerin_lemma.values()):
    guerin_bigrams.append(create_bigrams(i))

# %%
pdv_bigrams = []

for i in list(pdv_lemma.values()):
    pdv_bigrams.append(create_bigrams(i))

# %%
for value in tqdm(pdv_bigrams):
    
    comparaison_bi_grams(value)
# Out:
# 100%|███████████████████████████████████████| 2048/2048 [02:28<00:00, 13.77it/s]

# %%
un_bi = substitute_keys(matches,pdv_lemma)
deux_bi = transform_sentences_to_keys(un_bi,guerin_lemma)
deux_bi = remove_duplicates_from_dict_values(deux_bi)

# %%
count_bigrams = {}

for key, value in deux.items():
    count_bigrams[key] = len(value)

# %%
count_sentences_bigrams = {}
#nombre de phrases qui ont au moins un bigramme similaire avec une phrase de guérin. 

for i in tqdm(range(363)):
    filtered_dict = {key: value for key, value in count_bigrams.items() if key.startswith(f"pdv_{i+1}_")}
    count_sentences_bigrams[f'pdv_{i+1}'] = sum(filtered_dict.values())
# Out:
# 100%|███████████████████████████████████████| 363/363 [00:00<00:00, 3148.19it/s]

# %%
keys = list(count_sentences_bigrams.keys())
values = list(count_sentences_bigrams.values())

livre_1 = {}
livre_2 = {}
livre_3 = {}
livre_4 = {}
livre_5 = {}
livre_6 = {}

for i in range(len(keys)):
    if i < 33:
        livre_1[keys[i]] = values[i]
    if 32 < i < 92:
        livre_2[keys[i]] = values[i]
    if 91 < i < 179:
        livre_3[keys[i]] = values[i]
    if 178 < i < 195:
        livre_4[keys[i]] = values[i]
    if 194 < i < 331:
        livre_5[keys[i]] = values[i]
    if 330 < i < 364:
        livre_6[keys[i]] = values[i]

# %%
livre1 = pd.DataFrame(list(livre_1.items()), columns=['Key', 'Value'])
statistics1 = pd.DataFrame(livre1['Value'].describe())

livre2 = pd.DataFrame(list(livre_2.items()), columns=['Key', 'Value'])
statistics2 = pd.DataFrame(livre2['Value'].describe())

livre3 = pd.DataFrame(list(livre_3.items()), columns=['Key', 'Value'])
statistics3 = pd.DataFrame(livre3['Value'].describe())

livre4 = pd.DataFrame(list(livre_4.items()), columns=['Key', 'Value'])
statistics4 = pd.DataFrame(livre4['Value'].describe())

livre5 = pd.DataFrame(list(livre_5.items()), columns=['Key', 'Value'])
statistics5 = pd.DataFrame(livre5['Value'].describe())

livre6 = pd.DataFrame(list(livre_6.items()), columns=['Key', 'Value'])
statistics6 = pd.DataFrame(livre6['Value'].describe())

# %%
livre1_array = np.array(livre1['Value'].tolist())
livre2_array = np.array(livre2['Value'].tolist())
livre3_array = np.array(livre3['Value'].tolist())
livre4_array = np.array(livre4['Value'].tolist())
livre5_array = np.array(livre5['Value'].tolist())
livre6_array = np.array(livre6['Value'].tolist())
list_livre = [livre1_array,livre2_array,livre3_array,livre4_array,livre5_array,livre6_array]

# %%
sns.set(style="whitegrid")
facecolor = '#eaeaf2'
fig, ax = plt.subplots(figsize=(12, 9), facecolor=facecolor)
sns.boxplot(data=list_livre, palette="Set3",showmeans=True,
            meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
plt.yscale("log")
ax.set_ylabel('Nombres de correspondances de bigrams de mots dans les textes de Guérin', 
              fontsize=12)
custom_labels = ['livre 1','livre 2','livre 3','livre 4','livre 5','livre 6']
plt.xticks(range(len(custom_labels)), custom_labels)
plt.title('Nombre de phrases de Guérin dans lesquelles on retrouve au moins un bigram en commun avec Pierre de la Vigne')
# Out:
# Text(0.5, 1.0, 'Nombre de phrases de Guérin dans lesquelles on retrouve au moins un bigram en commun avec Pierre de la Vigne')

# %%
liste_bigrams = [sum(livre_1.values()),sum(livre_2.values()),sum(livre_3.values()),
                     sum(livre_4.values()),sum(livre_5.values()),sum(livre_6.values())]

# %%
liste_bigrams
# Out:
# [6330, 5862, 8332, 1224, 14920, 10271]

# %% [markdown]
# # Trigrams

# %%
guerin_trigrams = []

for i in list(guerin_lemma.values()):
    guerin_trigrams.append(create_trigrams(i))

# %%
guerin_trigrams
# Out:
# [[('philippus', 'uniuersus', 'cor'),
#   ('uniuersus', 'cor', 'habeo'),
#   ('cor', 'habeo', 'condecet'),
#   ('habeo', 'condecet', 'inimicus1'),
#   ('condecet', 'inimicus1', 'nequicia'),
#   ('inimicus1', 'nequicia', 'impello'),
#   ('nequicia', 'impello', 'totus'),
#   ('impello', 'totus', 'conatus'),
#   ('totus', 'conatus', 'repello'),
#   ('conatus', 'repello', 'quies'),
#   ('repello', 'quies', 'pax'),
#   ('quies', 'pax', 'regnum'),
#   ('pax', 'regnum', 'fidelis2'),
#   ('regnum', 'fidelis2', 'incola'),
#   ('fidelis2', 'incola', 'idem'),
#   ('incola', 'idem', 'auxilior'),
#   ('idem', 'auxilior', 'deus'),
#   ('auxilior', 'deus', 'precipue'),
#   ('deus', 'precipue', 'medio'),
#   ('precipue', 'medio', 'subdo'),
#   ('medio', 'subdo', 'subsidium'),
#   ('subdo', 'subsidium', 'procuro'),
#   ('subsidium', 'procuro', 'prouideo'),
#   ('procuro', 'prouideo', 'mercator'),
#   ('prouideo', 'mercator', 'alius'),
#   ('mercator', 'alius', 'subdo'),
#   ('alius', 'subdo', 'mercatura'),
#   ('subdo', 'mercatura', 'negocium'),
#   ('mercatura', 'negocium', 'alius'),
#   ('negocium', 'alius', 'impedio'),
#   ('alius', 'impedio', 'ualeo'),
#   ('impedio', 'ualeo', 'expono'),
#   ('ualeo', 'expono', 'sui1'),
#   ('expono', 'sui1', 'periculum'),
#   ('sui1', 'periculum', 'quicumque1'),
#   ('periculum', 'quicumque1', 'notus2'),
#   ('quicumque1', 'notus2', 'facio'),
#   ('notus2', 'facio', 'licet1'),
#   ('facio', 'licet1', 'personaliter'),
#   ('licet1', 'personaliter', 'intendo'),
#   ('personaliter', 'intendo', 'propono'),
#   ('intendo', 'propono', 'cuc'),
#   ('propono', 'cuc', 'uia'),
#   ('cuc', 'uia', 'modus'),
#   ('uia', 'modus', 'multus'),
#   ('modus', 'multus', 'exquisitus'),
#   ('multus', 'exquisitus', 'finaliter'),
#   ('exquisitus', 'finaliter', 'delibero'),
#   ('finaliter', 'delibero', 'cumcus'),
#   ('delibero', 'cumcus', 'peritus'),
#   ('cumcus', 'peritus', 'talis'),
#   ('peritus', 'talis', 'et?'),
#   ('talis', 'et?', 'quamplus'),
#   ('et?', 'quamplus', 'famosus'),
#   ('quamplus', 'famosus', 'consilium'),
#   ('famosus', 'consilium', 'certus'),
#   ('consilium', 'certus', 'procedo1'),
#   ('certus', 'procedo1', 'uia'),
#   ('procedo1', 'uia', 'supper'),
#   ('uia', 'supper', 'prouideo'),
#   ('supper', 'prouideo', 'utilis'),
#   ('prouideo', 'utilis', 'saluber'),
#   ('utilis', 'saluber', 'diligo3'),
#   ('saluber', 'diligo3', 'fidelis2'),
#   ('diligo3', 'fidelis2', 'semis1'),
#   ('fidelis2', 'semis1', 'ruppis'),
#   ('semis1', 'ruppis', 'choardus'),
#   ('ruppis', 'choardus', 'eo1')],
#  [('uigeo', 'miles', 'qui1'),
#   ('miles', 'qui1', 'pictauensis'),
#   ('qui1', 'pictauensis', 'mitto'),
#   ('pictauensis', 'mitto', 'senescallia'),
#   ('mitto', 'senescallia', 'apperior'),
#   ('senescallia', 'apperior', 'alter'),
#   ('apperior', 'alter', 'senescallus'),
#   ('alter', 'senescallus', 'idem'),
#   ('senescallus', 'idem', 'senescallis'),
#   ('idem', 'senescallis', 'expedio'),
#   ('senescallis', 'expedio', 'uideo'),
#   ('expedio', 'uideo', 'declaro'),
#   ('uideo', 'declaro', 'uidelicet'),
#   ('declaro', 'uidelicet', 'uenio'),
#   ('uidelicet', 'uenio', 'uos'),
#   ('uenio', 'uos', 'factum'),
#   ('uos', 'factum', 'uerisimiliter'),
#   ('factum', 'uerisimiliter', 'omnis'),
#   ('uerisimiliter', 'omnis', 'tango'),
#   ('omnis', 'tango', 'certus'),
#   ('tango', 'certus', 'numerus'),
#   ('certus', 'numerus', 'seruiens'),
#   ('numerus', 'seruiens', 'arma'),
#   ('seruiens', 'arma', 'uadium'),
#   ('arma', 'uadium', 'seu1'),
#   ('uadium', 'seu1', 'stipendium'),
#   ('seu1', 'stipendium', 'diues'),
#   ('stipendium', 'diues', 'secundum2'),
#   ('diues', 'secundum2', 'uis'),
#   ('secundum2', 'uis', 'facultas'),
#   ('uis', 'facultas', 'idem'),
#   ('facultas', 'idem', 'certus'),
#   ('idem', 'certus', 'tempus1'),
#   ('certus', 'tempus1', 'prout'),
#   ('tempus1', 'prout', 'duco'),
#   ('prout', 'duco', 'considero'),
#   ('duco', 'considero', 'negocium'),
#   ('considero', 'negocium', 'statuo')],
#  [('do', 'omnis', 'subdo'),
#   ('omnis', 'subdo', 'preso'),
#   ('subdo', 'preso', 'mandatum'),
#   ('preso', 'mandatum', 'idem'),
#   ('mandatum', 'idem', 'commissarius'),
#   ('idem', 'commissarius', 'hic1'),
#   ('commissarius', 'hic1', 'pars'),
#   ('hic1', 'pars', 'prompte'),
#   ('pars', 'prompte', 'deuotius'),
#   ('prompte', 'deuotius', 'pareo'),
#   ('deuotius', 'pareo', 'intendo')],
#  [('quis1', 'res', 'testimimonium')],
#  [('ago', 'parisius', 'festum'),
#   ('parisius', 'festum', 'beatus'),
#   ('festum', 'beatus', 'martinus'),
#   ('beatus', 'martinus', 'annus'),
#   ('martinus', 'annus', 'dominus'),
#   ('annus', 'dominus', 'mitis'),
#   ('dominus', 'mitis', 'cic'),
#   ('mitis', 'cic', 'secundus1')],
#  [('philippus', 'deus', 'gratia'),
#   ('deus', 'gratia', 'francior'),
#   ('gratia', 'francior', 'rex')],
#  [('notus2', 'facio', 'uniuersus'),
#   ('facio', 'uniuersus', 'preso'),
#   ('uniuersus', 'preso', 'futurus'),
#   ('preso', 'futurus', 'dilectus1'),
#   ('futurus', 'dilectus1', 'miles'),
#   ('dilectus1', 'miles', 'noster'),
#   ('miles', 'noster', 'guido'),
#   ('noster', 'guido', 'baucayum'),
#   ('guido', 'baucayum', 'sui1'),
#   ('baucayum', 'sui1', 'suus'),
#   ('sui1', 'suus', 'que'),
#   ('suus', 'que', 'heres'),
#   ('que', 'heres', 'perpetuus'),
#   ('heres', 'perpetuus', 'concedo1'),
#   ('perpetuus', 'concedo1', 'usagium'),
#   ('concedo1', 'usagium', 'totus'),
#   ('usagium', 'totus', 'forestus'),
#   ('totus', 'forestus', 'monsterolum'),
#   ('forestus', 'monsterolum', 'bonnen'),
#   ('monsterolum', 'bonnen', 'boscus'),
#   ('bonnen', 'boscus', 'mombuil'),
#   ('boscus', 'mombuil', 'omnis'),
#   ('mombuil', 'omnis', 'necessitas'),
#   ('omnis', 'necessitas', 'expedicio'),
#   ('necessitas', 'expedicio', 'suus'),
#   ('expedicio', 'suus', 'dictum'),
#   ('suus', 'dictum', 'usagium'),
#   ('dictum', 'usagium', 'aliquis'),
#   ('usagium', 'aliquis', 'uendo'),
#   ('aliquis', 'uendo', 'muto2'),
#   ('uendo', 'muto2', 'uolens'),
#   ('muto2', 'uolens', 'dictum'),
#   ('uolens', 'dictum', 'forestus'),
#   ('dictum', 'forestus', 'monsterolum'),
#   ('forestus', 'monsterolum', 'libro'),
#   ('monsterolum', 'libro', 'monstro'),
#   ('libro', 'monstro', 'usagium'),
#   ('monstro', 'usagium', 'pres'),
#   ('usagium', 'pres', 'dictum'),
#   ('pres', 'dictum', 'habeo'),
#   ('dictum', 'habeo', 'forestus'),
#   ('habeo', 'forestus', 'mombuil'),
#   ('forestus', 'mombuil', 'usagium'),
#   ('mombuil', 'usagium', 'capio2'),
#   ('usagium', 'capio2', 'habeo'),
#   ('capio2', 'habeo', 'seruio'),
#   ('habeo', 'seruio', 'libro'),
#   ('seruio', 'libro', 'pars'),
#   ('libro', 'pars', 'dico2'),
#   ('pars', 'dico2', 'forestus'),
#   ('dico2', 'forestus', 'qui1'),
#   ('forestus', 'qui1', 'domus'),
#   ('qui1', 'domus', 'dictum'),
#   ('domus', 'dictum', 'guido'),
#   ('dictum', 'guido', 'sum1'),
#   ('guido', 'sum1', 'propinqui'),
#   ('sum1', 'propinqui', 'facio')],
#  [('ratus', 'stabilis', 'maneo'),
#   ('stabilis', 'maneo', 'sum1'),
#   ('maneo', 'sum1', 'preso'),
#   ('sum1', 'preso', 'noster'),
#   ('preso', 'noster', 'facio'),
#   ('noster', 'facio', 'appono'),
#   ('facio', 'appono', 'sigillum')],
#  [('ago', 'fons', 'bliaudus'),
#   ('fons', 'bliaudus', 'annus'),
#   ('bliaudus', 'annus', 'dominus'),
#   ('annus', 'dominus', 'cic'),
#   ('dominus', 'cic', 'secundus1'),
#   ('cic', 'secundus1', 'mensis')],
#  [('philippus', 'deus', 'gratia'),
#   ('deus', 'gratia', 'franci'),
#   ('gratia', 'franci', 'rex'),
#   ('franci', 'rex', 'salus')],
#  [('mando2', 'tu', 'quatinus'),
#   ('tu', 'quatinus', 'quisquis1'),
#   ('quatinus', 'quisquis1', 'fructus'),
#   ('quisquis1', 'fructus', 'prouenus'),
#   ('fructus', 'prouenus', 'tu'),
#   ('prouenus', 'tu', 'beneficium'),
#   ('tu', 'beneficium', 'ecclesiasticus'),
#   ('beneficium', 'ecclesiasticus', 'tu'),
#   ('ecclesiasticus', 'tu', 'sum1'),
#   ('tu', 'sum1', 'persona'),
#   ('sum1', 'persona', 'regnum'),
#   ('persona', 'regnum', 'noster'),
#   ('regnum', 'noster', 'absum1'),
#   ('noster', 'absum1', 'tempus1'),
#   ('absum1', 'tempus1', 'leuo1'),
#   ('tempus1', 'leuo1', 'mando2'),
#   ('leuo1', 'mando2', 'leuo1'),
#   ('mando2', 'leuo1', 'exsisto'),
#   ('leuo1', 'exsisto', 'receptus1'),
#   ('exsisto', 'receptus1', 'uideo'),
#   ('receptus1', 'uideo', 'preso'),
#   ('uideo', 'preso', 'mitto'),
#   ('preso', 'mitto', 'libero'),
#   ('mitto', 'libero', 'thesaurarius2'),
#   ('libero', 'thesaurarius2', 'parisius'),
#   ('thesaurarius2', 'parisius', 'templum'),
#   ('parisius', 'templum', 'hic1'),
#   ('templum', 'hic1', 'resto'),
#   ('hic1', 'resto', 'leuo1'),
#   ('resto', 'leuo1', 'leuis1'),
#   ('leuo1', 'leuis1', 'exigo'),
#   ('leuis1', 'exigo', 'indilate'),
#   ('exigo', 'indilate', 'idem'),
#   ('indilate', 'idem', 'thesaurarius2'),
#   ('idem', 'thesaurarius2', 'absque2'),
#   ('thesaurarius2', 'absque2', 'dilacio'),
#   ('absque2', 'dilacio', 'quilibet'),
#   ('dilacio', 'quilibet', 'transmitto'),
#   ('quilibet', 'transmitto', 'quantum4'),
#   ('transmitto', 'quantum4', 'preso'),
#   ('quantum4', 'preso', 'miser'),
#   ('preso', 'miser', 'quantum3'),
#   ('miser', 'quantum3', 'resto'),
#   ('quantum3', 'resto', 'leuo1'),
#   ('resto', 'leuo1', 'beneficium'),
#   ('leuo1', 'beneficium', 'nomen'),
#   ('beneficium', 'nomen', 'persona'),
#   ('nomen', 'persona', 'ipse'),
#   ('persona', 'ipse', 'diligo3'),
#   ('ipse', 'diligo3', 'fidellis'),
#   ('diligo3', 'fidellis', 'gens'),
#   ('fidellis', 'gens', 'compotor'),
#   ('gens', 'compotor', 'noster'),
#   ('compotor', 'noster', 'parisius'),
#   ('noster', 'parisius', 'cito2'),
#   ('parisius', 'cito2', 'rescribo')],
#  [('do', 'tholosus', 'dies'),
#   ('tholosus', 'dies', 'mare'),
#   ('dies', 'mare', 'Epipphania'),
#   ('mare', 'Epipphania', 'mitto'),
#   ('Epipphania', 'mitto', 'ccico'),
#   ('mitto', 'ccico', 'is')],
#  [('philippus', 'deus', 'gratia'),
#   ('deus', 'gratia', 'francor'),
#   ('gratia', 'francor', 'rex'),
#   ('francor', 'rex', 'superintendo'),
#   ('rex', 'superintendo', 'negocio'),
#   ('superintendo', 'negocio', 'subuencio'),
#   ('negocio', 'subuencio', 'noue'),
#   ('subuencio', 'noue', 'nos'),
#   ('noue', 'nos', 'pictauensis'),
#   ('nos', 'pictauensis', 'senescallia'),
#   ('pictauensis', 'senescallia', 'concedo1'),
#   ('senescallia', 'concedo1', 'salus')],
#  [('dilcetus', 'fidelis2', 'miles'),
#   ('fidelis2', 'miles', 'noster'),
#   ('miles', 'noster', 'semis?'),
#   ('noster', 'semis?', 'ruppis'),
#   ('semis?', 'ruppis', 'cauardus'),
#   ('ruppis', 'cauardus', 'pars'),
#   ('cauardus', 'pars', 'pictauiensis'),
#   ('pars', 'pictauiensis', 'senescallie'),
#   ('pictauiensis', 'senescallie', 'deputo'),
#   ('senescallie', 'deputo', 'unus'),
#   ('deputo', 'unus', 'senescallus'),
#   ('unus', 'senescallus', 'noster'),
#   ('senescallus', 'noster', 'pictaueniens'),
#   ('noster', 'pictaueniens', 'noster'),
#   ('pictaueniens', 'noster', 'presens'),
#   ('noster', 'presens', 'flandrensis'),
#   ('presens', 'flandrensis', 'exercitus1'),
#   ('flandrensis', 'exercitus1', 'gens'),
#   ('exercitus1', 'gens', 'arma'),
#   ('gens', 'arma', 'nos'),
#   ('arma', 'nos', 'cum3'),
#   ('nos', 'cum3', 'dico2'),
#   ('cum3', 'dico2', 'uenio'),
#   ('dico2', 'uenio', 'exercitus1'),
#   ('uenio', 'exercitus1', 'debeo'),
#   ('exercitus1', 'debeo', 'retineo'),
#   ('debeo', 'retineo', 'certus'),
#   ('retineo', 'certus', 'forma'),
#   ('certus', 'forma', 'nos'),
#   ('forma', 'nos', 'committo'),
#   ('nos', 'committo', 'mando2'),
#   ('committo', 'mando2', 'uos'),
#   ('mando2', 'uos', 'quatinus'),
#   ('uos', 'quatinus', 'qui1'),
#   ('quatinus', 'qui1', 'alter'),
#   ('qui1', 'alter', 'retineo'),
#   ('alter', 'retineo', 'contingo1'),
#   ('retineo', 'contingo1', 'mutuo2'),
#   ('contingo1', 'mutuo2', 'facio'),
#   ('mutuo2', 'facio', 'libero'),
#   ('facio', 'libero', 'superus'),
#   ('libero', 'superus', 'pecunie'),
#   ('superus', 'pecunie', 'miles'),
#   ('pecunie', 'miles', 'senescallus'),
#   ('miles', 'senescallus', 'alter'),
#   ('senescallus', 'alter', 'sum1'),
#   ('alter', 'sum1', 'requiro'),
#   ('sum1', 'requiro', 'retineo'),
#   ('requiro', 'retineo', 'penes'),
#   ('retineo', 'penes', 'uos'),
#   ('penes', 'uos', 'littera'),
#   ('uos', 'littera', 'superus'),
#   ('littera', 'superus', 'quis1'),
#   ('superus', 'quis1', 'hic1'),
#   ('quis1', 'hic1', 'pars'),
#   ('hic1', 'pars', 'alter'),
#   ('pars', 'alter', 'mandatum'),
#   ('alter', 'mandatum', 'trado'),
#   ('mandatum', 'trado', 'contineo')],
#  [('do', 'pontisso', 'dies'),
#   ('pontisso', 'dies', 'uiium'),
#   ('dies', 'uiium', 'magnus'),
#   ('uiium', 'magnus', 'annus'),
#   ('magnus', 'annus', 'dominus'),
#   ('annus', 'dominus', 'mitto'),
#   ('dominus', 'mitto', 'cic'),
#   ('mitto', 'cic', 'quartus')],
#  [('philippus', 'deus', 'gratia'),
#   ('deus', 'gratia', 'francior'),
#   ('gratia', 'francior', 'rex')],
#  [('notus2', 'facio', 'uniuersus'),
#   ('facio', 'uniuersus', 'preso'),
#   ('uniuersus', 'preso', 'futurus'),
#   ('preso', 'futurus', 'gratus'),
#   ('futurus', 'gratus', 'considero'),
#   ('gratus', 'considero', 'obsequium'),
#   ('considero', 'obsequium', 'qui1'),
#   ('obsequium', 'qui1', 'dilectus1'),
#   ('qui1', 'dilectus1', 'symon'),
#   ('dilectus1', 'symon', 'ruppis'),
#   ('symon', 'ruppis', 'cauardus'),
#   ('ruppis', 'cauardus', 'miles'),
#   ('cauardus', 'miles', 'nos'),
#   ('miles', 'nos', 'exhibeo'),
#   ('nos', 'exhibeo', 'factum'),
#   ('exhibeo', 'factum', 'guerra'),
#   ('factum', 'guerra', 'noster'),
#   ('guerra', 'noster', 'alius'),
#   ('noster', 'alius', 'exhibeo'),
#   ('alius', 'exhibeo', 'incessanter'),
#   ('exhibeo', 'incessanter', 'idem'),
#   ('incessanter', 'idem', 'miles'),
#   ('idem', 'miles', 'seruicium'),
#   ('miles', 'seruicium', 'recompensacio'),
#   ('seruicium', 'recompensacio', 'huiusmodi'),
#   ('recompensacio', 'huiusmodi', 'concedo1'),
#   ('huiusmodi', 'concedo1', 'dono'),
#   ('concedo1', 'dono', 'centum'),
#   ('dono', 'centum', 'libra'),
#   ('centum', 'libra', 'turonensis'),
#   ('libra', 'turonensis', 'paruus1'),
#   ('turonensis', 'paruus1', 'annuus'),
#   ('paruus1', 'annuus', 'perpetuus'),
#   ('annuus', 'perpetuus', 'reddo'),
#   ('perpetuus', 'reddo', 'graciose'),
#   ('reddo', 'graciose', 'idem'),
#   ('graciose', 'idem', 'miles'),
#   ('idem', 'miles', 'liberi'),
#   ('miles', 'liberi', 'matrimonnium'),
#   ('liberi', 'matrimonnium', 'procreo'),
#   ('matrimonnium', 'procreo', 'legitimus'),
#   ('procreo', 'legitimus', 'procreo'),
#   ('legitimus', 'procreo', 'recta'),
#   ('procreo', 'recta', 'linea'),
#   ('recta', 'linea', 'descendo'),
#   ('linea', 'descendo', 'percipio'),
#   ('descendo', 'percipio', 'perpetuo2'),
#   ('percipio', 'perpetuo2', 'hereditarie'),
#   ('perpetuo2', 'hereditarie', 'possideo'),
#   ('hereditarie', 'possideo', 'thesaurus'),
#   ('possideo', 'thesaurus', 'noster'),
#   ('thesaurus', 'noster', 'parisius'),
#   ('noster', 'parisius', 'annus'),
#   ('parisius', 'annus', 'singulus'),
#   ('annus', 'singulus', 'festum'),
#   ('singulus', 'festum', 'dominicus'),
#   ('festum', 'dominicus', 'ascensio'),
#   ('dominicus', 'ascensio', 'donec'),
#   ('ascensio', 'donec', 'alibi'),
#   ('donec', 'alibi', 'duco'),
#   ('alibi', 'duco', 'assideo'),
#   ('duco', 'assideo', 'huiusmodi'),
#   ('assideo', 'huiusmodi', 'reddo'),
#   ('huiusmodi', 'reddo', 'pres'),
#   ('reddo', 'pres', 'dico2'),
#   ('pres', 'dico2', 'miles'),
#   ('dico2', 'miles', 'suus'),
#   ('miles', 'suus', 'que'),
#   ('suus', 'que', 'pres'),
#   ('que', 'pres', 'dictum'),
#   ('pres', 'dictum', 'liberi'),
#   ('dictum', 'liberi', 'heres'),
#   ('liberi', 'heres', 'nos'),
#   ('heres', 'nos', 'successor'),
#   ('nos', 'successor', 'homagium'),
#   ('successor', 'homagium', 'facio'),
#   ('homagium', 'facio', 'teneo'),
#   ('facio', 'teneo', 'ratus'),
#   ('teneo', 'ratus', 'stabilis'),
#   ('ratus', 'stabilis', 'perseuero'),
#   ('stabilis', 'perseuero', 'preso'),
#   ('perseuero', 'preso', 'noster'),
#   ('preso', 'noster', 'facio'),
#   ('noster', 'facio', 'appono'),
#   ('facio', 'appono', 'sigillum'),
#   ('appono', 'sigillum', 'ago'),
#   ('sigillum', 'ago', 'abbatia'),
#   ('ago', 'abbatia', 'regalis'),
#   ('abbatia', 'regalis', 'beatus'),
#   ('regalis', 'beatus', 'mare'),
#   ('beatus', 'mare', 'prope1'),
#   ('mare', 'prope1', 'pontisarus'),
#   ('prope1', 'pontisarus', 'annus'),
#   ('pontisarus', 'annus', 'dominus'),
#   ('annus', 'dominus', 'mitis'),
#   ('dominus', 'mitis', 'cic'),
#   ('mitis', 'cic', 'quartus'),
#   ('cic', 'quartus', 'dies'),
#   ('quartus', 'dies', 'lune'),
#   ('dies', 'lune', 'festus'),
#   ('lune', 'festus', 'omnis'),
#   ('festus', 'omnis', 'sanctus')],
#  [('philippus', 'deus', 'gratia'),
#   ('deus', 'gratia', 'francior'),
#   ('gratia', 'francior', 'rex')],
#  [('notus2', 'facio', 'uniuersus'),
#   ('facio', 'uniuersus', 'preso'),
#   ('uniuersus', 'preso', 'futurus'),
#   ('preso', 'futurus', 'gratus'),
#   ('futurus', 'gratus', 'considero'),
#   ('gratus', 'considero', 'obsequium'),
#   ('considero', 'obsequium', 'qui1'),
#   ('obsequium', 'qui1', 'dilectus1'),
#   ('qui1', 'dilectus1', 'Ioannes'),
#   ('dilectus1', 'Ioannes', 'uigerius'),
#   ('Ioannes', 'uigerius', 'miles'),
#   ('uigerius', 'miles', 'diucius'),
#   ('miles', 'diucius', 'nos'),
#   ('diucius', 'nos', 'exhibeo'),
#   ('nos', 'exhibeo', 'incessanter'),
#   ('exhibeo', 'incessanter', 'impendo'),
#   ('incessanter', 'impendo', 'idem'),
#   ('impendo', 'idem', 'liberi'),
#   ('idem', 'liberi', 'legitimus'),
#   ('liberi', 'legitimus', 'matrimonium'),
#   ('legitimus', 'matrimonium', 'procreo'),
#   ('matrimonium', 'procreo', 'procreo'),
#   ('procreo', 'procreo', 'rectus'),
#   ('procreo', 'rectus', 'linea'),
#   ('rectus', 'linea', 'descendo'),
#   ('linea', 'descendo', 'octoginta'),
#   ('descendo', 'octoginta', 'libra'),
#   ('octoginta', 'libra', 'turonensis'),
#   ('libra', 'turonensis', 'paruus1'),
#   ('turonensis', 'paruus1', 'annuus'),
#   ('paruus1', 'annuus', 'reddo'),
#   ('annuus', 'reddo', 'aymardus'),
#   ('reddo', 'aymardus', 'Ualencia'),
#   ('aymardus', 'Ualencia', 'miles'),
#   ('Ualencia', 'miles', 'nos'),
#   ('miles', 'nos', 'racio'),
#   ('nos', 'racio', 'forefacio'),
#   ('racio', 'forefacio', 'noster'),
#   ('forefacio', 'noster', 'soneuillum'),
#   ('noster', 'soneuillum', 'ab'),
#   ('soneuillum', 'ab', 'nos'),
#   ('ab', 'nos', 'perpetuus'),
#   ('nos', 'perpetuus', 'firmus'),
#   ('perpetuus', 'firmus', 'dico2'),
#   ('firmus', 'dico2', 'recipio'),
#   ('dico2', 'recipio', 'annuatim'),
#   ('recipio', 'annuatim', 'teneo'),
#   ('annuatim', 'teneo', 'preso'),
#   ('teneo', 'preso', 'tenor'),
#   ('preso', 'tenor', 'graciose'),
#   ('tenor', 'graciose', 'concedo1'),
#   ('graciose', 'concedo1', 'dono'),
#   ('concedo1', 'dono', 'percipio'),
#   ('dono', 'percipio', 'idem'),
#   ('percipio', 'idem', 'ioannes'),
#   ('idem', 'ioannes', 'liberi'),
#   ('ioannes', 'liberi', 'dico2'),
#   ('liberi', 'dico2', 'sum1'),
#   ('dico2', 'sum1', 'perpetuo2'),
#   ('sum1', 'perpetuo2', 'hereditarius'),
#   ('perpetuo2', 'hereditarius', 'terminus'),
#   ('hereditarius', 'terminus', 'consuesco'),
#   ('terminus', 'consuesco', 'prout'),
#   ('consuesco', 'prout', 'annus'),
#   ('prout', 'annus', 'percipio'),
#   ('annus', 'percipio', 'soleo')],
#  [('do', 'senescallus', 'noster'),
#   ('senescallus', 'noster', 'xanctonensis'),
#   ('noster', 'xanctonensis', 'modernus'),
#   ('xanctonensis', 'modernus', 'tempus1'),
#   ('modernus', 'tempus1', 'sum1'),
#   ('tempus1', 'sum1', 'idem'),
#   ('sum1', 'idem', 'preso'),
#   ('idem', 'preso', 'mandatum'),
#   ('preso', 'mandatum', 'prefo'),
#   ('mandatum', 'prefo', 'miles'),
#   ('prefo', 'miles', 'noster'),
#   ('miles', 'noster', 'liberi'),
#   ('noster', 'liberi', 'premitto'),
#   ('liberi', 'premitto', 'dico2'),
#   ('premitto', 'dico2', 'octoginta'),
#   ('dico2', 'octoginta', 'libra'),
#   ('octoginta', 'libra', 'annus'),
#   ('libra', 'annus', 'singulus'),
#   ('annus', 'singulus', 'forma'),
#   ('singulus', 'forma', 'predico'),
#   ('forma', 'predico', 'absque2'),
#   ('predico', 'absque2', 'difficultas'),
#   ('absque2', 'difficultas', 'quicumque1'),
#   ('difficultas', 'quicumque1', 'alter'),
#   ('quicumque1', 'alter', 'exspectatio'),
#   ('alter', 'exspectatio', 'mandatum'),
#   ('exspectatio', 'mandatum', 'facio'),
#   ('mandatum', 'facio', 'libero')],
#  [('huiusmodi', 'reddo', 'prefor'),
#   ('reddo', 'prefor', 'miles'),
#   ('prefor', 'miles', 'suus'),
#   ('miles', 'suus', 'que'),
#   ('suus', 'que', 'predico'),
#   ('que', 'predico', 'liberi'),
#   ('predico', 'liberi', 'heres'),
#   ('liberi', 'heres', 'nos'),
#   ('heres', 'nos', 'successor'),
#   ('nos', 'successor', 'homagium'),
#   ('successor', 'homagium', 'facio'),
#   ('homagium', 'facio', 'teneo'),
#   ('facio', 'teneo', 'ratus'),
#   ('teneo', 'ratus', 'stabilis'),
#   ('ratus', 'stabilis', 'perseuero'),
#   ('stabilis', 'perseuero', 'preso'),
#   ('perseuero', 'preso', 'noster'),
#   ('preso', 'noster', 'facio'),
#   ('noster', 'facio', 'appono'),
#   ('facio', 'appono', 'sigillum')],
#  [('ago', 'Huorcii', 'dies'),
#   ('Huorcii', 'dies', 'Iuppiter'),
#   ('dies', 'Iuppiter', 'festus'),
#   ('Iuppiter', 'festus', 'omnis'),
#   ('festus', 'omnis', 'sanctus'),
#   ('omnis', 'sanctus', 'annus'),
#   ('sanctus', 'annus', 'dominus'),
#   ('annus', 'dominus', 'mitto'),
#   ('dominus', 'mitto', 'cic'),
#   ('mitto', 'cic', 'quartus')],
#  [('philippus', 'deus', 'gratia'),
#   ('deus', 'gratia', 'francior'),
#   ('gratia', 'francior', 'rex')],
#  [('notus2', 'facio', 'uniuersus'),
#   ('facio', 'uniuersus', 'preso'),
#   ('uniuersus', 'preso', 'futurus'),
#   ('preso', 'futurus', 'pridem'),
#   ('futurus', 'pridem', 'dilectus2'),
#   ('pridem', 'dilectus2', 'symonus'),
#   ('dilectus2', 'symonus', 'ruppis'),
#   ('symonus', 'ruppis', 'cauardus'),
#   ('ruppis', 'cauardus', 'miles'),
#   ('cauardus', 'miles', 'noster'),
#   ('miles', 'noster', 'obtentus'),
#   ('noster', 'obtentus', 'gratus'),
#   ('obtentus', 'gratus', 'seruicium'),
#   ('gratus', 'seruicium', 'nos'),
#   ('seruicium', 'nos', 'idem'),
#   ('nos', 'idem', 'impensus'),
#   ('idem', 'impensus', 'centum'),
#   ('impensus', 'centum', 'libra'),
#   ('centum', 'libra', 'annuus'),
#   ('libra', 'annuus', 'perpetuus'),
#   ('annuus', 'perpetuus', 'reddo'),
#   ('perpetuus', 'reddo', 'turonensis'),
#   ('reddo', 'turonensis', 'paruus1'),
#   ('turonensis', 'paruus1', 'do'),
#   ('paruus1', 'do', 'concedo1'),
#   ('do', 'concedo1', 'percipio'),
#   ('concedo1', 'percipio', 'idem'),
#   ('percipio', 'idem', 'miles'),
#   ('idem', 'miles', 'liberi'),
#   ('miles', 'liberi', 'legitimus'),
#   ('liberi', 'legitimus', 'matrimonium'),
#   ('legitimus', 'matrimonium', 'procreo'),
#   ('matrimonium', 'procreo', 'procreo'),
#   ('procreo', 'procreo', 'recta'),
#   ('procreo', 'recta', 'linea'),
#   ('recta', 'linea', 'descendo'),
#   ('linea', 'descendo', 'tantummodo'),
#   ('descendo', 'tantummodo', 'perpetuo2'),
#   ('tantummodo', 'perpetuo2', 'hereditarius'),
#   ('perpetuo2', 'hereditarius', 'annus'),
#   ('hereditarius', 'annus', 'singulus'),
#   ('annus', 'singulus', 'thesaurus'),
#   ('singulus', 'thesaurus', 'noster'),
#   ('thesaurus', 'noster', 'parisius'),
#   ('noster', 'parisius', 'festum'),
#   ('parisius', 'festum', 'ascensio'),
#   ('festum', 'ascensio', 'dominicus'),
#   ('ascensio', 'dominicus', 'donec'),
#   ('dominicus', 'donec', 'alibi'),
#   ('donec', 'alibi', 'duco'),
#   ('alibi', 'duco', 'assideo'),
#   ('duco', 'assideo', 'reddo'),
#   ('assideo', 'reddo', 'dico2'),
#   ('reddo', 'dico2', 'miles'),
#   ('dico2', 'miles', 'suus'),
#   ('miles', 'suus', 'que'),
#   ('suus', 'que', 'pres'),
#   ('que', 'pres', 'dico?'),
#   ('pres', 'dico?', 'liberi'),
#   ('dico?', 'liberi', 'heres'),
#   ('liberi', 'heres', 'nos'),
#   ('heres', 'nos', 'successor'),
#   ('nos', 'successor', 'homagium'),
#   ('successor', 'homagium', 'facio'),
#   ('homagium', 'facio', 'teneo'),
#   ('facio', 'teneo', 'prefo'),
#   ('teneo', 'prefo', 'miles'),
#   ('prefo', 'miles', 'gratia'),
#   ('miles', 'gratia', 'hic1'),
#   ('gratia', 'hic1', 'pars'),
#   ('hic1', 'pars', 'facio'),
#   ('pars', 'facio', 'specialis'),
#   ('facio', 'specialis', 'uolens'),
#   ('specialis', 'uolens', 'peticio'),
#   ('uolens', 'peticio', 'miles'),
#   ('peticio', 'miles', 'uendicio'),
#   ('miles', 'uendicio', 'ipse'),
#   ('uendicio', 'ipse', 'dictum'),
#   ('ipse', 'dictum', 'reddo'),
#   ('dictum', 'reddo', 'facio'),
#   ('reddo', 'facio', 'gaufridus'),
#   ('facio', 'gaufridus', 'sauigniacus'),
#   ('gaufridus', 'sauigniacus', 'ualletum'),
#   ('sauigniacus', 'ualletum', 'noster'),
#   ('ualletum', 'noster', 'prout'),
#   ('noster', 'prout', 'coram1'),
#   ('prout', 'coram1', 'nos'),
#   ('coram1', 'nos', 'assero?'),
#   ('nos', 'assero?', 'miles'),
#   ('assero?', 'miles', 'conuencio'),
#   ('miles', 'conuencio', 'uendicio'),
#   ('conuencio', 'uendicio', 'sequor'),
#   ('uendicio', 'sequor', 'ratus'),
#   ('sequor', 'ratus', 'habeo'),
#   ('ratus', 'habeo', 'gratus'),
#   ('habeo', 'gratus', 'tenor'),
#   ('gratus', 'tenor', 'preso'),
#   ('tenor', 'preso', 'approbo'),
#   ('preso', 'approbo', 'certus'),
#   ('approbo', 'certus', 'sciencia'),
#   ('certus', 'sciencia', 'confirmo'),
#   ('sciencia', 'confirmo', 'concedo'),
#   ('confirmo', 'concedo', 'que'),
#   ('concedo', 'que', 'sui1'),
#   ('que', 'sui1', 'heres'),
#   ('sui1', 'heres', 'successor'),
#   ('heres', 'successor', 'causa'),
#   ('successor', 'causa', 'habeo'),
#   ('causa', 'habeo', 'predico'),
#   ('habeo', 'predico', 'centum'),
#   ('predico', 'centum', 'libra'),
#   ('centum', 'libra', 'turonensis'),
#   ('libra', 'turonensis', 'annuus'),
#   ('turonensis', 'annuus', 'perpetuus'),
#   ('annuus', 'perpetuus', 'reddo'),
#   ('perpetuus', 'reddo', 'sepedicta'),
#   ('reddo', 'sepedicta', 'habeo'),
#   ('sepedicta', 'habeo', 'teneo'),
#   ('habeo', 'teneo', 'percipio'),
#   ('teneo', 'percipio', 'possideo'),
#   ('percipio', 'possideo', 'annus'),
#   ('possideo', 'annus', 'singulus'),
#   ('annus', 'singulus', 'imperpetuus'),
#   ('singulus', 'imperpetuus', 'thesaurus'),
#   ('imperpetuus', 'thesaurus', 'noster'),
#   ('thesaurus', 'noster', 'parisius'),
#   ('noster', 'parisius', 'pres'),
#   ('parisius', 'pres', 'dictum'),
#   ('pres', 'dictum', 'terminus'),
#   ('dictum', 'terminus', 'dominicus'),
#   ('terminus', 'dominicus', 'ascensio'),
#   ('dominicus', 'ascensio', 'pacificus'),
#   ('ascensio', 'pacificus', 'quies'),
#   ('pacificus', 'quies', 'donec'),
#   ('quies', 'donec', 'alibi'),
#   ('donec', 'alibi', 'duco'),
#   ('alibi', 'duco', 'assido')],
#  [('huiusmodi', 'reddo', 'gonugus'),
#   ('reddo', 'gonugus', 'heres'),
#   ('gonugus', 'heres', 'successor'),
#   ('heres', 'successor', 'causa'),
#   ('successor', 'causa', 'habeo'),
#   ('causa', 'habeo', 'nos'),
#   ('habeo', 'nos', 'successor'),
#   ('nos', 'successor', 'homagium'),
#   ('successor', 'homagium', 'facio'),
#   ('homagium', 'facio', 'teneo')],
#  [('saluus', 'alius', 'ius1'),
#   ('alius', 'ius1', 'noster'),
#   ('ius1', 'noster', 'omnis'),
#   ('noster', 'omnis', 'alienus1')],
#  [('do', 'thesaurarius2', 'modernus'),
#   ('thesaurarius2', 'modernus', 'tempus1'),
#   ('modernus', 'tempus1', 'sum1'),
#   ('tempus1', 'sum1', 'idem'),
#   ('sum1', 'idem', 'preso'),
#   ('idem', 'preso', 'mandatum'),
#   ('preso', 'mandatum', 'idem'),
#   ('mandatum', 'idem', 'gonugus'),
#   ('idem', 'gonugus', 'heres'),
#   ('gonugus', 'heres', 'successor'),
#   ('heres', 'successor', 'causa'),
#   ('successor', 'causa', 'habeo'),
#   ('causa', 'habeo', 'predico'),
#   ('habeo', 'predico', 'sepedicta'),
#   ('predico', 'sepedicta', 'centum'),
#   ('sepedicta', 'centum', 'libra'),
#   ('centum', 'libra', 'turonensis'),
#   ('libra', 'turonensis', 'annuus'),
#   ('turonensis', 'annuus', 'perpetuus'),
#   ('annuus', 'perpetuus', 'reddo'),
#   ('perpetuus', 'reddo', 'annus'),
#   ('reddo', 'annus', 'singulus'),
#   ('annus', 'singulus', 'supradico'),
#   ('singulus', 'supradico', 'terminus'),
#   ('supradico', 'terminus', 'absque2'),
#   ('terminus', 'absque2', 'alter'),
#   ('absque2', 'alter', 'exspectatio'),
#   ('alter', 'exspectatio', 'mandatum'),
#   ('exspectatio', 'mandatum', 'persoluo'),
#   ('mandatum', 'persoluo', 'ratus'),
#   ('persoluo', 'ratus', 'stabilis'),
#   ('ratus', 'stabilis', 'perseuero'),
#   ('stabilis', 'perseuero', 'preso'),
#   ('perseuero', 'preso', 'littera'),
#   ('preso', 'littera', 'noster'),
#   ('littera', 'noster', 'facio'),
#   ('noster', 'facio', 'appono'),
#   ('facio', 'appono', 'sigillum')],
#  [('ago', 'courciacum', 'logio'),
#   ('courciacum', 'logio', 'annus'),
#   ('logio', 'annus', 'dominus'),
#   ('annus', 'dominus', 'mitto'),
#   ('dominus', 'mitto', 'cic'),
#   ('mitto', 'cic', 'quintus'),
#   ('cic', 'quintus', 'mensis'),
#   ('quintus', 'mensis', 'iulius')],
#  [('philippus', 'deus', 'gratia'),
#   ('deus', 'gratia', 'francor'),
#   ('gratia', 'francor', 'rex'),
#   ('francor', 'rex', 'senescallum'),
#   ('rex', 'senescallum', 'pictaueniens'),
#   ('senescallum', 'pictaueniens', 'salus')],
#  [('superintendo', 'negocio', 'subuentio'),
#   ('negocio', 'subuentio', 'num'),
#   ('subuentio', 'num', 'decimalis'),
#   ('num', 'decimalis', 'alius'),
#   ('decimalis', 'alius', 'qui1'),
#   ('alius', 'qui1', 'libet'),
#   ('qui1', 'libet', 'uester'),
#   ('libet', 'uester', 'senescalis'),
#   ('uester', 'senescalis', 'ressors'),
#   ('senescalis', 'ressors', 'nos'),
#   ('ressors', 'nos', 'deputo'),
#   ('nos', 'deputo', 'multus'),
#   ('deputo', 'multus', 'litera'),
#   ('multus', 'litera', 'noster'),
#   ('litera', 'noster', 'excitatorius'),
#   ('noster', 'excitatorius', 'mitto'),
#   ('excitatorius', 'mitto', 'omnis'),
#   ('mitto', 'omnis', 'acceleratio'),
#   ('omnis', 'acceleratio', 'leuo1'),
#   ('acceleratio', 'leuo1', 'mitto'),
#   ('leuo1', 'mitto', 'parisius'),
#   ('mitto', 'parisius', 'templum'),
#   ('parisius', 'templum', 'pecunia'),
#   ('templum', 'pecunia', 'subuentio'),
#   ('pecunia', 'subuentio', 'hic1'),
#   ('subuentio', 'hic1', 'modus'),
#   ('hic1', 'modus', 'contingo1'),
#   ('modus', 'contingo1', 'inuenio'),
#   ('contingo1', 'inuenio', 'sum1'),
#   ('inuenio', 'sum1', 'hactenus'),
#   ('sum1', 'hactenus', 'negligens'),
#   ('hactenus', 'negligens', 'is'),
#   ('negligens', 'is', 'que'),
#   ('is', 'que', 'itero'),
#   ('que', 'itero', 'excito1'),
#   ('itero', 'excito1', 'alius'),
#   ('excito1', 'alius', 'littera'),
#   ('alius', 'littera', 'noster'),
#   ('littera', 'noster', 'mando2'),
#   ('noster', 'mando2', 'omnis'),
#   ('mando2', 'omnis', 'pecunia'),
#   ('omnis', 'pecunia', 'nos'),
#   ('pecunia', 'nos', 'deputo'),
#   ('nos', 'deputo', 'quomodocum'),
#   ('deputo', 'quomodocum', 'que'),
#   ('quomodocum', 'que', 'leuo1'),
#   ('que', 'leuo1', 'saluus'),
#   ('leuo1', 'saluus', 'securus'),
#   ('saluus', 'securus', 'conductus'),
#   ('securus', 'conductus', 'mitto'),
#   ('conductus', 'mitto', 'indilate'),
#   ('mitto', 'indilate', 'parisius'),
#   ('indilate', 'parisius', 'templum'),
#   ('parisius', 'templum', 'preso'),
#   ('templum', 'preso', 'scio'),
#   ('preso', 'scio', 'dilectus2'),
#   ('scio', 'dilectus2', 'noster'),
#   ('dilectus2', 'noster', 'guiardus'),
#   ('noster', 'guiardus', 'leo'),
#   ('guiardus', 'leo', 'ciuis'),
#   ('leo', 'ciuis', 'parisiensis'),
#   ('ciuis', 'parisiensis', 'lator'),
#   ('parisiensis', 'lator', 'preso'),
#   ('lator', 'preso', 'qui1'),
#   ('preso', 'qui1', 'propter2'),
#   ('qui1', 'propter2', 'pars'),
#   ('propter2', 'pars', 'ille'),
#   ('pars', 'ille', 'duco'),
#   ('ille', 'duco', 'destino')],
#  [('mando2', 'uos', 'quatinus'),
#   ('uos', 'quatinus', 'relacio'),
#   ('quatinus', 'relacio', 'prefatus'),
#   ('relacio', 'prefatus', 'guiar'),
#   ('prefatus', 'guiar', 'uos'),
#   ('guiar', 'uos', 'consto'),
#   ('uos', 'consto', 'superintendo'),
#   ('consto', 'superintendo', 'prefatus'),
#   ('superintendo', 'prefatus', 'sum1'),
#   ('prefatus', 'sum1', 'negligencia'),
#   ('sum1', 'negligencia', 'premitto'),
#   ('negligencia', 'premitto', 'uos'),
#   ('premitto', 'uos', 'pecunia'),
#   ('uos', 'pecunia', 'totus'),
#   ('pecunia', 'totus', 'deputo'),
#   ('totus', 'deputo', 'recipio'),
#   ('deputo', 'recipio', 'ubicum'),
#   ('recipio', 'ubicum', 'que'),
#   ('ubicum', 'que', 'sum1'),
#   ('que', 'sum1', 'leuo2'),
#   ('sum1', 'leuo2', 'indilo'),
#   ('leuo2', 'indilo', 'preso'),
#   ('indilo', 'preso', 'sciens'),
#   ('preso', 'sciens', 'prefo'),
#   ('sciens', 'prefo', 'guiardus'),
#   ('prefo', 'guiardus', 'mitto'),
#   ('guiardus', 'mitto', 'quantocie'),
#   ('mitto', 'quantocie', 'saluus'),
#   ('quantocie', 'saluus', 'securus'),
#   ('saluus', 'securus', 'conductus'),
#   ('securus', 'conductus', 'parisius'),
#   ('conductus', 'parisius', 'templum'),
#   ('parisius', 'templum', 'scio'),
#   ('templum', 'scio', 'uos'),
#   ('scio', 'uos', 'grauiter'),
#   ('uos', 'grauiter', 'punio'),
#   ('grauiter', 'punio', 'propono'),
#   ('punio', 'propono', 'commitatus'),
#   ('propono', 'commitatus', 'negligentia'),
#   ('commitatus', 'negligentia', 'hic1'),
#   ('negligentia', 'hic1', 'pars')],
#  [('ago', 'parisius', 'dies'),
#   ('parisius', 'dies', 'uicesima'),
#   ('dies', 'uicesima', 'mensis'),
#   ('uicesima', 'mensis', 'september'),
#   ('mensis', 'september', 'annus'),
#   ('september', 'annus', 'dominus'),
#   ('annus', 'dominus', 'mitis'),
#   ('dominus', 'mitis', 'cic'),
#   ('mitis', 'cic', 'quintus')],
#  [('philippus', 'deus', 'gratia'),
#   ('deus', 'gratia', 'francor'),
#   ('gratia', 'francor', 'rex'),
#   ('francor', 'rex', 'senescallum'),
#   ('rex', 'senescallum', 'pictaueniens'),
#   ('senescallum', 'pictaueniens', 'salus')],
#  [('certus', 'causa', 'mando2'),
#   ('causa', 'mando2', 'uos'),
#   ('mando2', 'uos', 'precipio'),
#   ('uos', 'precipio', 'precipio'),
#   ('precipio', 'precipio', 'mando2'),
#   ('precipio', 'mando2', 'quatinus'),
#   ('mando2', 'quatinus', 'omnis'),
#   ('quatinus', 'omnis', 'pecunia'),
#   ('omnis', 'pecunia', 'qui1'),
#   ('pecunia', 'qui1', 'expleo'),
#   ('qui1', 'expleo', 'obuencio'),
#   ('expleo', 'obuencio', 'emolumentum'),
#   ('obuencio', 'emolumentum', 'subuencio'),
#   ('emolumentum', 'subuencio', 'libet'),
#   ('subuencio', 'libet', 'uester'),
#   ('libet', 'uester', 'senescallis'),
#   ('uester', 'senescallis', 'colligo3'),
#   ('senescallis', 'colligo3', 'leuo1'),
#   ('colligo3', 'leuo1', 'exsisto'),
#   ('leuo1', 'exsisto', 'que'),
#   ('exsisto', 'que', 'insto'),
#   ('que', 'insto', 'festus'),
#   ('insto', 'festus', 'omnis'),
#   ('festus', 'omnis', 'sanctus'),
#   ('omnis', 'sanctus', 'colligo3'),
#   ('sanctus', 'colligo3', 'leuo1'),
#   ('colligo3', 'leuo1', 'remaneo'),
#   ('leuo1', 'remaneo', 'quicumque1'),
#   ('remaneo', 'quicumque1', 'colligo3'),
#   ('quicumque1', 'colligo3', 'debeo'),
#   ('colligo3', 'debeo', 'leuo1'),
#   ('debeo', 'leuo1', 'quinque'),
#   ('leuo1', 'quinque', 'septimani'),
#   ('quinque', 'septimani', 'receptio'),
#   ('septimani', 'receptio', 'preso'),
#   ('receptio', 'preso', 'omnis'),
#   ('preso', 'omnis', 'dilacio'),
#   ('omnis', 'dilacio', 'excusacio'),
#   ('dilacio', 'excusacio', 'remoueo'),
#   ('excusacio', 'remoueo', 'parisius'),
#   ('remoueo', 'parisius', 'templum'),
#   ('parisius', 'templum', 'procuro'),
#   ('templum', 'procuro', 'celeriter'),
#   ('procuro', 'celeriter', 'diligenter'),
#   ('celeriter', 'diligenter', 'affero'),
#   ('diligenter', 'affero', 'uester'),
#   ('affero', 'uester', 'ratio'),
#   ('uester', 'ratio', 'applico'),
#   ('ratio', 'applico', 'uos'),
#   ('applico', 'uos', 'que'),
#   ('uos', 'que', 'ibidem'),
#   ('que', 'ibidem', 'personaliter'),
#   ('ibidem', 'personaliter', 'intersum1'),
#   ('personaliter', 'intersum1', 'superr'),
#   ('intersum1', 'superr', 'explecto'),
#   ('superr', 'explecto', '#'),
#   ('explecto', '#', '#'),
#   ('#', '#', 'superrum'),
#   ('#', 'superrum', 'explecto'),
#   ('superrum', 'explecto', '#'),
#   ('explecto', '#', '#'),
#   ('#', '#', 'obuencio'),
#   ('#', 'obuencio', 'emolumentum'),
#   ('obuencio', 'emolumentum', 'subuencio'),
#   ('emolumentum', 'subuencio', 'pres'),
#   ('subuencio', 'pres', 'dictum'),
#   ('pres', 'dictum', 'computo'),
#   ('dictum', 'computo', 'reddo'),
#   ('computo', 'reddo', 'legitimus'),
#   ('reddo', 'legitimus', 'ratio'),
#   ('legitimus', 'ratio', 'premitto'),
#   ('ratio', 'premitto', 'aliquis'),
#   ('premitto', 'aliquis', 'sum1'),
#   ('aliquis', 'sum1', 'quomodo1'),
#   ('sum1', 'quomodo1', 'libet'),
#   ('quomodo1', 'libet', 'defectus1'),
#   ('libet', 'defectus1', 'uos'),
#   ('defectus1', 'uos', 'extunc'),
#   ('uos', 'extunc', 'reddo'),
#   ('extunc', 'reddo', 'castelleto'),
#   ('reddo', 'castelleto', 'noster'),
#   ('castelleto', 'noster', 'parisiensis'),
#   ('noster', 'parisiensis', 'corporaliter'),
#   ('parisiensis', 'corporaliter', 'noster'),
#   ('corporaliter', 'noster', 'carcer'),
#   ('noster', 'carcer', 'mancipo'),
#   ('carcer', 'mancipo', 'negligencia'),
#   ('mancipo', 'negligencia', 'diligencia'),
#   ('negligencia', 'diligencia', 'uester'),
#   ('diligencia', 'uester', 'habeo'),
#   ('uester', 'habeo', 'plenus'),
#   ('habeo', 'plenus', 'ualeo'),
#   ('plenus', 'ualeo', 'certitudo'),
#   ('ualeo', 'certitudo', 'mando2'),
#   ('certitudo', 'mando2', 'uos'),
#   ('mando2', 'uos', 'precipio'),
#   ('uos', 'precipio', 'quatinus'),
#   ('precipio', 'quatinus', 'dies'),
#   ('quatinus', 'dies', 'hora'),
#   ('dies', 'hora', 'preso'),
#   ('hora', 'preso', 'littera'),
#   ('preso', 'littera', 'uos'),
#   ('littera', 'uos', 'recipio'),
#   ('uos', 'recipio', 'contingo1'),
#   ('recipio', 'contingo1', 'diligo3'),
#   ('contingo1', 'diligo3', 'fidellis'),
#   ('diligo3', 'fidellis', 'thesaurarius2'),
#   ('fidellis', 'thesaurarius2', 'nnostri'),
#   ('thesaurarius2', 'nnostri', 'templum'),
#   ('nnostri', 'templum', 'parisiensis'),
#   ('templum', 'parisiensis', 'lator'),
#   ('parisiensis', 'lator', 'preso'),
#   ('lator', 'preso', 'litterator'),
#   ('preso', 'litterator', 'significo'),
#   ('litterator', 'significo', 'curo')],
#  [('do', 'parisius', 'idem'),
#   ('parisius', 'idem', 'dies'),
#   ('idem', 'dies', 'october'),
#   ('dies', 'october', 'annus'),
#   ('october', 'annus', 'dominus'),
#   ('annus', 'dominus', 'mitto'),
#   ('dominus', 'mitto', 'cic'),
#   ('mitto', 'cic', 'quintus')],
#  [('philippus', 'deus', 'gratia'),
#   ('deus', 'gratia', 'francior'),
#   ('gratia', 'francior', 'rex')],
#  [('notus2', 'facio', 'uniuersus'),
#   ('facio', 'uniuersus', 'preso'),
#   ('uniuersus', 'preso', 'futurus'),
#   ('preso', 'futurus', 'religiose'),
#   ('futurus', 'religiose', 'mulier'),
#   ('religiose', 'mulier', 'abbatitor'),
#   ('mulier', 'abbatitor', 'conuentus'),
#   ('abbatitor', 'conuentus', 'monasterium'),
#   ('conuentus', 'monasterium', 'fons'),
#   ('monasterium', 'fons', 'ebraudium'),
#   ('fons', 'ebraudium', 'ialleagium'),
#   ('ebraudium', 'ialleagium', 'mensuragium'),
#   ('ialleagium', 'mensuragium', 'missio'),
#   ('mensuragium', 'missio', 'seu2'),
#   ('missio', 'seu2', 'posicio'),
#   ('seu2', 'posicio', 'preconsus'),
#   ('posicio', 'preconsus', 'uinum'),
#   ('preconsus', 'uinum', 'Prisias'),
#   ('uinum', 'Prisias', 'que'),
#   ('Prisias', 'que', 'uengen'),
#   ('que', 'uengen', 'cias'),
#   ('uengen', 'cias', 'emo'),
#   ('cias', 'emo', 'que'),
#   ('emo', 'que', 'exinde'),
#   ('que', 'exinde', 'prouenio'),
#   ('exinde', 'prouenio', 'possum1'),
#   ('prouenio', 'possum1', 'qui1'),
#   ('possum1', 'qui1', 'omnis'),
#   ('qui1', 'omnis', 'conquestus'),
#   ('omnis', 'conquestus', 'idem'),
#   ('conquestus', 'idem', 'religiosus'),
#   ('idem', 'religiosus', 'facio'),
#   ('religiosus', 'facio', 'guillelmus'),
#   ('facio', 'guillelmus', 'puteus'),
#   ('guillelmus', 'puteus', 'guillelmus'),
#   ('puteus', 'guillelmus', 'berneza'),
#   ('guillelmus', 'berneza', 'miles'),
#   ('berneza', 'miles', 'halmericus'),
#   ('miles', 'halmericus', 'bernezaus'),
#   ('halmericus', 'bernezaus', 'armiger1'),
#   ('bernezaus', 'armiger1', 'loudunus'),
#   ('armiger1', 'loudunus', 'teneo'),
#   ('loudunus', 'teneo', 'possideo'),
#   ('teneo', 'possideo', 'hereditarie'),
#   ('possideo', 'hereditarie', 'nos'),
#   ('hereditarie', 'nos', 'causa'),
#   ('nos', 'causa', 'pure'),
#   ('causa', 'pure', 'permutacio'),
#   ('pure', 'permutacio', 'seu1'),
#   ('permutacio', 'seu1', 'escambii'),
#   ('seu1', 'escambii', 'totaliter'),
#   ('escambii', 'totaliter', 'hereditarie'),
#   ('totaliter', 'hereditarie', 'dimitto'),
#   ('hereditarie', 'dimitto', 'teneo'),
#   ('dimitto', 'teneo', 'possideo'),
#   ('teneo', 'possideo', 'ab'),
#   ('possideo', 'ab', 'nos'),
#   ('ab', 'nos', 'heres'),
#   ('nos', 'heres', 'pperpetuus'),
#   ('heres', 'pperpetuus', 'quisquis1'),
#   ('pperpetuus', 'quisquis1', 'ius1'),
#   ('quisquis1', 'ius1', 'actio'),
#   ('ius1', 'actio', 'prietas'),
#   ('actio', 'prietas', 'possessio'),
#   ('prietas', 'possessio', 'dominium'),
#   ('possessio', 'dominium', 'premitto'),
#   ('dominium', 'premitto', 'habeo'),
#   ('premitto', 'habeo', 'habeo'),
#   ('habeo', 'habeo', 'possum1'),
#   ('habeo', 'possum1', 'quicumque1'),
#   ('possum1', 'quicumque1', 'titulus'),
#   ('quicumque1', 'titulus', 'transfero'),
#   ('titulus', 'transfero', 'nos'),
#   ('transfero', 'nos', 'successor'),
#   ('nos', 'successor', 'saluus'),
#   ('successor', 'saluus', 'libertas'),
#   ('saluus', 'libertas', 'franchisium'),
#   ('libertas', 'franchisium', 'homo'),
#   ('franchisium', 'homo', 'suus'),
#   ('homo', 'suus', 'secundum2'),
#   ('suus', 'secundum2', 'tenor'),
#   ('secundum2', 'tenor', 'priuilegium'),
#   ('tenor', 'priuilegium', 'suus'),
#   ('priuilegium', 'suus', 'prout'),
#   ('suus', 'prout', 'hactenus'),
#   ('prout', 'hactenus', 'utor'),
#   ('hactenus', 'utor', 'consuesco')],
#  [('restitucio', 'seu1', 'recompensacio'),
#   ('seu1', 'recompensacio', 'premitto'),
#   ('recompensacio', 'premitto', 'ecia'),
#   ('premitto', 'ecia', 'premitto'),
#   ('ecia', 'premitto', 'quadraginta'),
#   ('premitto', 'quadraginta', 'libra'),
#   ('quadraginta', 'libra', 'turonensis'),
#   ('libra', 'turonensis', 'annuus'),
#   ('turonensis', 'annuus', 'perpetuus'),
#   ('annuus', 'perpetuus', 'reddo'),
#   ('perpetuus', 'reddo', 'idem'),
#   ('reddo', 'idem', 'abbatus'),
#   ('idem', 'abbatus', 'conuentus'),
#   ('abbatus', 'conuentus', 'sui1'),
#   ('conuentus', 'sui1', 'monasterium'),
#   ('sui1', 'monasterium', 'suus'),
#   ('monasterium', 'suus', 'predictum'),
#   ('suus', 'predictum', 'nomen'),
#   ('predictum', 'nomen', 'concedo1'),
#   ('nomen', 'concedo1', 'assigno'),
#   ('concedo1', 'assigno', 'capio2'),
#   ('assigno', 'capio2', 'annus'),
#   ('capio2', 'annus', 'quilibet'),
#   ('annus', 'quilibet', 'medietas'),
#   ('quilibet', 'medietas', 'uidelicet'),
#   ('medietas', 'uidelicet', 'festum'),
#   ('uidelicet', 'festum', 'omnis'),
#   ('festum', 'omnis', 'sanctus'),
#   ('omnis', 'sanctus', 'alius'),
#   ('sanctus', 'alius', 'medietas'),
#   ('alius', 'medietas', 'festum'),
#   ('medietas', 'festum', 'ascensio'),
#   ('festum', 'ascensio', 'dominus'),
#   ('ascensio', 'dominus', 'prouentus'),
#   ('dominus', 'prouentus', 'exitus'),
#   ('prouentus', 'exitus', 'emolumentum'),
#   ('exitus', 'emolumentum', 'predico'),
#   ('emolumentum', 'predico', 'idem'),
#   ('predico', 'idem', 'religiosus'),
#   ('idem', 'religiosus', 'specialiter'),
#   ('religiosus', 'specialiter', 'obligo2')],
#  [('uolo?', 'concedo1', 'religiose'),
#   ('concedo1', 'religiose', 'predico'),
#   ('religiose', 'predico', 'que'),
#   ('predico', 'que', 'monasterium'),
#   ('que', 'monasterium', 'predico'),
#   ('monasterium', 'predico', 'quadraginta'),
#   ('predico', 'quadraginta', 'libra'),
#   ('quadraginta', 'libra', 'annuus'),
#   ('libra', 'annuus', 'reddo'),
#   ('annuus', 'reddo', 'teneo'),
#   ('reddo', 'teneo', 'possideo'),
#   ('teneo', 'possideo', 'possum1'),
#   ('possideo', 'possum1', 'perpetuus'),
#   ('possum1', 'perpetuus', 'pacifice'),
#   ('perpetuus', 'pacifice', 'quies'),
#   ('pacifice', 'quies', 'absque2'),
#   ('quies', 'absque2', 'coactio'),
#   ('absque2', 'coactio', 'compulsio'),
#   ('coactio', 'compulsio', 'uendo'),
#   ('compulsio', 'uendo', 'extra2'),
#   ('uendo', 'extra2', 'manus1'),
#   ('extra2', 'manus1', 'pono'),
#   ('manus1', 'pono', 'puresto'),
#   ('pono', 'puresto', 'financia'),
#   ('puresto', 'financia', 'idem'),
#   ('financia', 'idem', 'donec'),
#   ('idem', 'donec', 'idem'),
#   ('donec', 'idem', 'alibi'),
#   ('idem', 'alibi', 'competo'),
#   ('alibi', 'competo', 'locus'),
#   ('competo', 'locus', 'forma'),
#   ('locus', 'forma', 'predico'),
#   ('forma', 'predico', 'duco'),
#   ('predico', 'duco', 'assido')],
#  [('do', 'prepono', 'lodunensis'),
#   ('prepono', 'lodunensis', 'tempus1'),
#   ('lodunensis', 'tempus1', 'sum1'),
#   ('tempus1', 'sum1', 'tenor'),
#   ('sum1', 'tenor', 'prresentia'),
#   ('tenor', 'prresentia', 'mandatum'),
#   ('prresentia', 'mandatum', 'dico?'),
#   ('mandatum', 'dico?', 'religiosus'),
#   ('dico?', 'religiosus', 'mandatum'),
#   ('religiosus', 'mandatum', 'dico?'),
#   ('mandatum', 'dico?', 'quadraginta'),
#   ('dico?', 'quadraginta', 'libra'),
#   ('quadraginta', 'libra', 'dico?'),
#   ('libra', 'dico?', 'terminus'),
#   ('dico?', 'terminus', 'annuatim'),
#   ('terminus', 'annuatim', 'persoluo'),
#   ('annuatim', 'persoluo', 'alter'),
#   ('persoluo', 'alter', 'exspectacio'),
#   ('alter', 'exspectacio', 'mandatum')],
#  [('eciam', 'do', 'ago'),
#   ('do', 'ago', 'dicte'),
#   ('ago', 'dicte', 'religiose'),
#   ('dicte', 'religiose', 'dico?'),
#   ('religiose', 'dico?', 'quadraginta'),
#   ('dico?', 'quadraginta', 'libra'),
#   ('quadraginta', 'libra', 'annuus'),
#   ('libra', 'annuus', 'reddo'),
#   ('annuus', 'reddo', 'ualor'),
#   ('reddo', 'ualor', 'alius'),
#   ('ualor', 'alius', 'possessio'),
#   ('alius', 'possessio', 'competo'),
#   ('possessio', 'competo', 'precium'),
#   ('competo', 'precium', 'noster'),
#   ('precium', 'noster', 'consensus'),
#   ('noster', 'consensus', 'acquiro'),
#   ('consensus', 'acquiro', 'dictum'),
#   ('acquiro', 'dictum', 'prex'),
#   ('dictum', 'prex', 'persoluo'),
#   ('prex', 'persoluo', 'facio'),
#   ('persoluo', 'facio', 'noster'),
#   ('facio', 'noster', 'concedo1'),
#   ('noster', 'concedo1', 'idem'),
#   ('concedo1', 'idem', 'possum1'),
#   ('idem', 'possum1', 'teneo'),
#   ('possum1', 'teneo', 'perpetuo2'),
#   ('teneo', 'perpetuo2', 'dictum'),
#   ('perpetuo2', 'dictum', 'quadraginta'),
#   ('dictum', 'quadraginta', 'libra'),
#   ('quadraginta', 'libra', 'teneo'),
#   ('libra', 'teneo', 'possum1'),
#   ('teneo', 'possum1', 'predicta'),
#   ('possum1', 'predicta', 'assisius'),
#   ('predicta', 'assisius', 'solucio'),
#   ('assisius', 'solucio', 'precior'),
#   ('solucio', 'precior', 'supradico')],
#  [('prepono', 'loduensus', 'predicta'),
#   ('loduensus', 'predicta', 'is'),
#   ('predicta', 'is', 'que'),
#   ('is', 'que', 'prouentus'),
#   ('que', 'prouentus', 'exitus'),
#   ('prouentus', 'exitus', 'emolumentum'),
#   ('exitus', 'emolumentum', 'prestacio'),
#   ('emolumentum', 'prestacio', 'seu1'),
#   ('prestacio', 'seu1', 'solutio'),
#   ('seu1', 'solutio', 'dictum'),
#   ('solutio', 'dictum', 'quadraginta'),
#   ('dictum', 'quadraginta', 'liber1'),
#   ('quadraginta', 'liber1', 'annuus'),
#   ('liber1', 'annuus', 'reddo'),
#   ('annuus', 'reddo', 'libero'),
#   ('reddo', 'libero', 'omnino'),
#   ('libero', 'omnino', 'firmus'),
#   ('omnino', 'firmus', 'permaneo'),
#   ('firmus', 'permaneo', 'sum1'),
#   ('permaneo', 'sum1', 'preso'),
#   ('sum1', 'preso', 'littera'),
#   ('preso', 'littera', 'noster'),
#   ('littera', 'noster', 'facio'),
#   ('noster', 'facio', 'appono'),
#   ('facio', 'appono', 'sigillum')],
#  [('ago', 'parisius', 'mensis'),
#   ('parisius', 'mensis', 'magnus'),
#   ('mensis', 'magnus', 'annus'),
#   ('magnus', 'annus', 'dominus'),
#   ('annus', 'dominus', 'millesimus'),
#   ('dominus', 'millesimus', 'cic'),
#   ('millesimus', 'cic', 'sextus')],
#  [('philippus', 'deus', 'gratiafranci'), ('deus', 'gratiafranci', 'rex')],
#  [('notus2', 'facio', 'uniuersus'),
#   ('facio', 'uniuersus', 'preso'),
#   ('uniuersus', 'preso', 'futurum'),
#   ('preso', 'futurum', 'littera'),
#   ('futurum', 'littera', 'inclutus'),
#   ('littera', 'inclutus', 'recordatio'),
#   ('inclutus', 'recordatio', 'precarus'),
#   ('recordatio', 'precarus', 'dominus'),
#   ('precarus', 'dominus', 'genitor'),
#   ('dominus', 'genitor', 'philippus'),
#   ('genitor', 'philippus', 'quondam'),
#   ('philippus', 'quondam', 'rex'),
#   ('quondam', 'rex', 'franci'),
#   ('rex', 'franci', 'uideo'),
#   ('franci', 'uideo', 'forma'),
#   ('uideo', 'forma', 'que'),
#   ('forma', 'que', 'sequor'),
#   ('que', 'sequor', 'contineo'),
#   ('sequor', 'contineo', 'philippus'),
#   ('contineo', 'philippus', 'deus'),
#   ('philippus', 'deus', 'gratia'),
#   ('deus', 'gratia', 'francis'),
#   ('gratia', 'francis', 'rex')],
#  [('notus2', 'facio', 'uniuersus'),
#   ('facio', 'uniuersus', 'preso'),
#   ('uniuersus', 'preso', 'futurum'),
#   ('preso', 'futurum', 'littera'),
#   ('futurum', 'littera', 'inclutus'),
#   ('littera', 'inclutus', 'recordatio'),
#   ('inclutus', 'recordatio', 'pres'),
#   ('recordatio', 'pres', 'karius'),
#   ('pres', 'karius', 'dominus'),
#   ('karius', 'dominus', 'genitor'),
#   ('dominus', 'genitor', 'ludouic'),
#   ('genitor', 'ludouic', 'rex'),
#   ('ludouic', 'rex', 'franci'),
#   ('rex', 'franci', 'uideo'),
#   ('franci', 'uideo', 'hec'),
#   ('uideo', 'hec', 'uerbum'),
#   ('hec', 'uerbum', 'ludouicus'),
#   ('uerbum', 'ludouicus', 'deus'),
#   ('ludouicus', 'deus', 'gratia'),
#   ('deus', 'gratia', 'franci'),
#   ('gratia', 'franci', 'rex')],
#  [('nosco', 'uniuersus', 'littera'),
#   ('uniuersus', 'littera', 'inclutus'),
#   ('littera', 'inclutus', 'recordacio'),
#   ('inclutus', 'recordacio', 'rex'),
#   ('recordacio', 'rex', 'philippus'),
#   ('rex', 'philippus', 'auus'),
#   ('philippus', 'auus', 'noster'),
#   ('auus', 'noster', 'uideo'),
#   ('noster', 'uideo', 'hic1'),
#   ('uideo', 'hic1', 'uerbum'),
#   ('hic1', 'uerbum', 'philippus'),
#   ('uerbum', 'philippus', 'deus'),
#   ('philippus', 'deus', 'gratia'),
#   ('deus', 'gratia', 'franci'),
#   ('gratia', 'franci', 'rex'),
#   ('franci', 'rex', 'omnis'),
#   ('rex', 'omnis', 'qui1'),
#   ('omnis', 'qui1', 'preso'),
#   ('qui1', 'preso', 'litterre'),
#   ('preso', 'litterre', 'peruenio'),
#   ('litterre', 'peruenio', 'salus')],
#  [('nosco', 'dilectus1', 'noster'),
#   ('dilectus1', 'noster', 'abbatus'),
# ...
#   ('facio', 'uoco', 'preso'),
#   ('uoco', 'preso', 'propter1'),
#   ('preso', 'propter1', 'procurator'),
#   ('propter1', 'procurator', 'abbatus'),
#   ('procurator', 'abbatus', 'conuentus'),
#   ('abbatus', 'conuentus', 'monasterium'),
#   ('conuentus', 'monasterium', 'Caroffensis'),
#   ('monasterium', 'Caroffensis', 'dominus'),
#   ('Caroffensis', 'dominus', 'rex'),
#   ('dominus', 'rex', 'senescallia'),
#   ('rex', 'senescallia', 'marchies'),
#   ('senescallia', 'marchies', 'nos'),
#   ('marchies', 'nos', 'que'),
#   ('nos', 'que', 'audio'),
#   ('que', 'audio', 'propono'),
#   ('audio', 'propono', 'hinc'),
#   ('propono', 'hinc', 'inde'),
#   ('hinc', 'inde', 'uideo'),
#   ('inde', 'uideo', 'dictum'),
#   ('uideo', 'dictum', 'articulus'),
#   ('dictum', 'articulus', 'inquestus'),
#   ('articulus', 'inquestus', 'dictum'),
#   ('inquestus', 'dictum', 'que'),
#   ('dictum', 'que', 'inquestus'),
#   ('que', 'inquestus', 'perficio'),
#   ('inquestus', 'perficio', 'dico2'),
#   ('perficio', 'dico2', 'uideo'),
#   ('dico2', 'uideo', 'eciam'),
#   ('uideo', 'eciam', 'do'),
#   ('eciam', 'do', 'littera'),
#   ('do', 'littera', 'priuilegium'),
#   ('littera', 'priuilegium', 'pars'),
#   ('priuilegium', 'pars', 'dico?'),
#   ('pars', 'dico?', 'monasterium'),
#   ('dico?', 'monasterium', 'exhibeo'),
#   ('monasterium', 'exhibeo', 'recipio'),
#   ('exhibeo', 'recipio', 'que'),
#   ('recipio', 'que', 'probacio'),
#   ('que', 'probacio', 'qui1'),
#   ('probacio', 'qui1', 'pars'),
#   ('qui1', 'pars', 'hinc'),
#   ('pars', 'hinc', 'inde'),
#   ('hinc', 'inde', 'produco'),
#   ('inde', 'produco', 'uolo3'),
#   ('produco', 'uolo3', 'deliberacio'),
#   ('uolo3', 'deliberacio', 'habeo'),
#   ('deliberacio', 'habeo', 'diligens'),
#   ('habeo', 'diligens', 'dictum'),
#   ('diligens', 'dictum', 'ballium'),
#   ('dictum', 'ballium', 'decanus'),
#   ('ballium', 'decanus', 'predico'),
#   ('decanus', 'predico', 'diu'),
#   ('predico', 'diu', 'palpo2'),
#   ('diu', 'palpo2', 'causes'),
#   ('palpo2', 'causes', 'meritum'),
#   ('causes', 'meritum', 'cognosco'),
#   ('meritum', 'cognosco', 'multus'),
#   ('cognosco', 'multus', 'alius'),
#   ('multus', 'alius', 'peritus'),
#   ('alius', 'peritus', 'ius1'),
#   ('peritus', 'ius1', 'regius'),
#   ('ius1', 'regius', 'foueo'),
#   ('regius', 'foueo', 'hic1'),
#   ('foueo', 'hic1', 'pars'),
#   ('hic1', 'pars', 'dico2'),
#   ('pars', 'dico2', 'pars'),
#   ('dico2', 'pars', 'transactio'),
#   ('pars', 'transactio', 'pax'),
#   ('transactio', 'pax', 'contentus1'),
#   ('pax', 'contentus1', 'commissio'),
#   ('contentus1', 'commissio', 'articulus'),
#   ('commissio', 'articulus', 'supradico'),
#   ('articulus', 'supradico', 'reduco'),
#   ('supradico', 'reduco', 'hic1'),
#   ('reduco', 'hic1', 'modus')],
#  [('uidelicet', 'nos', 'alius'),
#   ('nos', 'alius', 'dictum'),
#   ('alius', 'dictum', 'medio'),
#   ('dictum', 'medio', 'dico2'),
#   ('medio', 'dico2', 'pars'),
#   ('dico2', 'pars', 'concordalus'),
#   ('pars', 'concordalus', 'exsisto'),
#   ('concordalus', 'exsisto', 'ecia'),
#   ('exsisto', 'ecia', 'ordino'),
#   ('ecia', 'ordino', 'dictum'),
#   ('ordino', 'dictum', 'abbatus'),
#   ('dictum', 'abbatus', 'conuentus'),
#   ('abbatus', 'conuentus', 'homo'),
#   ('conuentus', 'homo', 'burgus'),
#   ('homo', 'burgus', 'carroffium'),
#   ('burgus', 'carroffium', 'omnimodus'),
#   ('carroffium', 'omnimodus', 'altus'),
#   ('omnimodus', 'altus', 'medius'),
#   ('altus', 'medius', 'bassus'),
#   ('medius', 'bassus', 'iusticia'),
#   ('bassus', 'iusticia', 'perpetuo2'),
#   ('iusticia', 'perpetuo2', 'remaneo'),
#   ('perpetuo2', 'remaneo', 'exercicium'),
#   ('remaneo', 'exercicium', 'omnimode'),
#   ('exercicium', 'omnimode', 'alte'),
#   ('omnimode', 'alte', 'medies'),
#   ('alte', 'medies', 'bassus'),
#   ('medies', 'bassus', 'iusticie'),
#   ('bassus', 'iusticie', 'gens'),
#   ('iusticie', 'gens', 'officialis'),
#   ('gens', 'officialis', 'dico?'),
#   ('officialis', 'dico?', 'dominus'),
#   ('dico?', 'dominus', 'rex'),
#   ('dominus', 'rex', 'racio'),
#   ('rex', 'racio', 'comitatus1'),
#   ('racio', 'comitatus1', 'marchies'),
#   ('comitatus1', 'marchies', 'comes'),
#   ('marchies', 'comes', 'tempus1'),
#   ('comes', 'tempus1', 'sum1'),
#   ('tempus1', 'sum1', 'impedio'),
#   ('sum1', 'impedio', 'quoquomodo1'),
#   ('impedio', 'quoquomodo1', 'excipio'),
#   ('quoquomodo1', 'excipio', 'casus'),
#   ('excipio', 'casus', 'homicidium'),
#   ('casus', 'homicidium', 'furtum'),
#   ('homicidium', 'furtum', 'seu1'),
#   ('furtum', 'seu1', 'latrocinium'),
#   ('seu1', 'latrocinium', 'adulterium'),
#   ('latrocinium', 'adulterium', 'rapio'),
#   ('adulterium', 'rapio', 'seu1'),
#   ('rapio', 'seu1', 'uiolencie'),
#   ('seu1', 'uiolencie', 'mulier'),
#   ('uiolencie', 'mulier', 'incendium'),
#   ('mulier', 'incendium', 'abortizacio'),
#   ('incendium', 'abortizacio', 'facio'),
#   ('abortizacio', 'facio', 'opportet'),
#   ('facio', 'opportet', 'mulier'),
#   ('opportet', 'mulier', 'incido1'),
#   ('mulier', 'incido1', 'qui1'),
#   ('incido1', 'qui1', 'casus'),
#   ('qui1', 'casus', 'omnimodo'),
#   ('casus', 'omnimodo', 'iusticia'),
#   ('omnimodo', 'iusticia', 'dominus'),
#   ('iusticia', 'dominus', 'rex'),
#   ('dominus', 'rex', 'racio'),
#   ('rex', 'racio', 'dico?'),
#   ('racio', 'dico?', 'comitatus1'),
#   ('dico?', 'comitatus1', 'perpetuo2'),
#   ('comitatus1', 'perpetuo2', 'remaneo')],
#  [('reseruo', 'eciam', 'dictum'),
#   ('eciam', 'dictum', 'dominus'),
#   ('dictum', 'dominus', 'rex'),
#   ('dominus', 'rex', 'racio'),
#   ('rex', 'racio', 'dico?'),
#   ('racio', 'dico?', 'comitatus1'),
#   ('dico?', 'comitatus1', 'exsequcio'),
#   ('comitatus1', 'exsequcio', 'casus'),
#   ('exsequcio', 'casus', 'dictum'),
#   ('casus', 'dictum', 'abbatus'),
#   ('dictum', 'abbatus', 'conuentus'),
#   ('abbatus', 'conuentus', 'uirtus'),
#   ('conuentus', 'uirtus', 'presens'),
#   ('uirtus', 'presens', 'transacio'),
#   ('presens', 'transacio', 'altus'),
#   ('transacio', 'altus', 'iusticia'),
#   ('altus', 'iusticia', 'remaneo'),
#   ('iusticia', 'remaneo', 'casus'),
#   ('remaneo', 'casus', 'sequor'),
#   ('casus', 'sequor', 'mors'),
#   ('sequor', 'mors', 'condempnacio'),
#   ('mors', 'condempnacio', 'abbatus'),
#   ('condempnacio', 'abbatus', 'conuentus'),
#   ('abbatus', 'conuentus', 'iusticiarius'),
#   ('conuentus', 'iusticiarius', 'hic1'),
#   ('iusticiarius', 'hic1', 'pars')],
#  [('ago', 'insuper1', 'ecia'),
#   ('insuper1', 'ecia', 'concordo'),
#   ('ecia', 'concordo', 'pars'),
#   ('concordo', 'pars', 'predico'),
#   ('pars', 'predico', 'preso'),
#   ('predico', 'preso', 'transacio'),
#   ('preso', 'transacio', 'seu2'),
#   ('transacio', 'seu2', 'pax'),
#   ('seu2', 'pax', 'littera'),
#   ('pax', 'littera', 'priuilegium'),
#   ('littera', 'priuilegium', 'constietudo'),
#   ('priuilegium', 'constietudo', 'libertas'),
#   ('constietudo', 'libertas', 'ius1'),
#   ('libertas', 'ius1', 'dictum'),
#   ('ius1', 'dictum', 'abbatus'),
#   ('dictum', 'abbatus', 'conuentus'),
#   ('abbatus', 'conuentus', 'is'),
#   ('conuentus', 'is', 'que'),
#   ('is', 'que', 'monasterium'),
#   ('que', 'monasterium', 'nullus'),
#   ('monasterium', 'nullus', 'fio'),
#   ('nullus', 'fio', 'preiudicium'),
#   ('fio', 'preiudicium', 'dominus'),
#   ('preiudicium', 'dominus', 'rex'),
#   ('dominus', 'rex', 'quoad1'),
#   ('rex', 'quoad1', 'ius1'),
#   ('quoad1', 'ius1', 'comitor'),
#   ('ius1', 'comitor', 'marchies'),
#   ('comitor', 'marchies', 'quatenus1'),
#   ('marchies', 'quatenus1', 'contentus1'),
#   ('quatenus1', 'contentus1', 'preso'),
#   ('contentus1', 'preso', 'transactio'),
#   ('preso', 'transactio', 'ex'),
#   ('transactio', 'ex', 'littera'),
#   ('ex', 'littera', 'derogo'),
#   ('littera', 'derogo', 'ius1'),
#   ('derogo', 'ius1', 'superus'),
#   ('ius1', 'superus', 'regie'),
#   ('superus', 'regie', 'dictum'),
#   ('regie', 'dictum', 'dominus'),
#   ('dictum', 'dominus', 'rex'),
#   ('dominus', 'rex', 'remaneo'),
#   ('rex', 'remaneo', 'semper')],
#  [('qui1', 'res', 'testimonium'),
#   ('res', 'testimonium', 'raymbaudus'),
#   ('testimonium', 'raymbaudus', 'predico'),
#   ('raymbaudus', 'predico', 'sigillum'),
#   ('predico', 'sigillum', 'noster'),
#   ('sigillum', 'noster', 'magnus'),
#   ('noster', 'magnus', 'contrasigillus'),
#   ('magnus', 'contrasigillus', 'paruus2'),
#   ('contrasigillus', 'paruus2', 'iste'),
#   ('paruus2', 'iste', 'commissio'),
#   ('iste', 'commissio', 'utor'),
#   ('commissio', 'utor', 'senescallus'),
#   ('utor', 'senescallus', 'predico'),
#   ('senescallus', 'predico', 'sigillum'),
#   ('predico', 'sigillum', 'noster'),
#   ('sigillum', 'noster', 'utor'),
#   ('noster', 'utor', 'unus'),
#   ('utor', 'unus', 'sigillum'),
#   ('unus', 'sigillum', 'dico?'),
#   ('sigillum', 'dico?', 'dominus'),
#   ('dico?', 'dominus', 'rex'),
#   ('dominus', 'rex', 'carroffium'),
#   ('rex', 'carroffium', 'constituo'),
#   ('carroffium', 'constituo', 'preso'),
#   ('constituo', 'preso', 'littera'),
#   ('preso', 'littera', 'rogo'),
#   ('littera', 'rogo', 'appono'),
#   ('rogo', 'appono', 'testimonium'),
#   ('appono', 'testimonium', 'ueritas'),
#   ('testimonium', 'ueritas', 'duco'),
#   ('ueritas', 'duco', 'appono')],
#  [('ego', 'helia', 'galter'),
#   ('helia', 'galter', 'clericus'),
#   ('galter', 'clericus', 'custos'),
#   ('clericus', 'custos', 'sigillum'),
#   ('custos', 'sigillum', 'dictum'),
#   ('sigillum', 'dictum', 'dominus'),
#   ('dictum', 'dominus', 'rex'),
#   ('dominus', 'rex', 'parrofium'),
#   ('rex', 'parrofium', 'constituo'),
#   ('parrofium', 'constituo', 'requisicio'),
#   ('constituo', 'requisicio', 'predicta'),
#   ('requisicio', 'predicta', 'dominus'),
#   ('predicta', 'dominus', 'rambaudus'),
#   ('dominus', 'rambaudus', 'senescallus'),
#   ('rambaudus', 'senescallus', 'sigillum'),
#   ('senescallus', 'sigillum', 'predico'),
#   ('sigillum', 'predico', 'unus'),
#   ('predico', 'unus', 'sigillum'),
#   ('unus', 'sigillum', 'preso'),
#   ('sigillum', 'preso', 'littera'),
#   ('preso', 'littera', 'appono'),
#   ('littera', 'appono', 'testimonium'),
#   ('appono', 'testimonium', 'ueritas')],
#  [('do', 'dies', 'lune'),
#   ('dies', 'lune', 'festus'),
#   ('lune', 'festus', 'omnis'),
#   ('festus', 'omnis', 'sanctus'),
#   ('omnis', 'sanctus', 'annus'),
#   ('sanctus', 'annus', 'dominus'),
#   ('annus', 'dominus', 'mitis'),
#   ('dominus', 'mitis', 'cic'),
#   ('mitis', 'cic', 'uicesimus'),
#   ('cic', 'uicesimus', 'sextus')],
#  [('omnis', 'singulus', 'suprascribo'),
#   ('singulus', 'suprascribo', 'contentus1'),
#   ('suprascribo', 'contentus1', 'littera'),
#   ('contentus1', 'littera', 'ratus'),
#   ('littera', 'ratus', 'habeo'),
#   ('ratus', 'habeo', 'gratus'),
#   ('habeo', 'gratus', 'uolo3'),
#   ('gratus', 'uolo3', 'laudo'),
#   ('uolo3', 'laudo', 'approbo'),
#   ('laudo', 'approbo', 'tenor'),
#   ('approbo', 'tenor', 'presencium'),
#   ('tenor', 'presencium', 'auctoritas'),
#   ('presencium', 'auctoritas', 'regius'),
#   ('auctoritas', 'regius', 'certus'),
#   ('regius', 'certus', 'sciencia'),
#   ('certus', 'sciencia', 'confirmo')],
#  [('noster', 'alius', 'alienus2'),
#   ('alius', 'alienus2', 'omnis'),
#   ('alienus2', 'omnis', 'ius1'),
#   ('omnis', 'ius1', 'saluus'),
#   ('ius1', 'saluus', 'firmus'),
#   ('saluus', 'firmus', 'stabilis'),
#   ('firmus', 'stabilis', 'perpetuo2'),
#   ('stabilis', 'perpetuo2', 'perseuero'),
#   ('perpetuo2', 'perseuero', 'preso'),
#   ('perseuero', 'preso', 'littera'),
#   ('preso', 'littera', 'noster'),
#   ('littera', 'noster', 'facio'),
#   ('noster', 'facio', 'appono'),
#   ('facio', 'appono', 'sigillum')],
#  [('ago', 'sanctus', 'remigium'),
#   ('sanctus', 'remigium', 'Uarenna'),
#   ('remigium', 'Uarenna', 'iuxta2'),
#   ('Uarenna', 'iuxta2', 'liger'),
#   ('iuxta2', 'liger', 'annus'),
#   ('liger', 'annus', 'dominus'),
#   ('annus', 'dominus', 'mitto'),
#   ('dominus', 'mitto', 'cic'),
#   ('mitto', 'cic', 'uicesimus'),
#   ('cic', 'uicesimus', 'nonus'),
#   ('uicesimus', 'nonus', 'mensis'),
#   ('nonus', 'mensis', 'augustus')],
#  [('dominus', 'rex', 'relacio'),
#   ('rex', 'relacio', 'uester'),
#   ('relacio', 'uester', 'dominus'),
#   ('uester', 'dominus', 'guido'),
#   ('dominus', 'guido', 'caprarius')],
#  [],
#  [],
#  [('philippus', 'deus', 'gratia'),
#   ('deus', 'gratia', 'francior'),
#   ('gratia', 'francior', 'rex')],
#  [('notus2', 'facio', 'uniuersus'),
#   ('facio', 'uniuersus', 'preso'),
#   ('uniuersus', 'preso', 'futurus'),
#   ('preso', 'futurus', 'infrascribo'),
#   ('futurus', 'infrascribo', 'uideo'),
#   ('infrascribo', 'uideo', 'littera'),
#   ('uideo', 'littera', 'forma'),
#   ('littera', 'forma', 'que'),
#   ('forma', 'que', 'sequor'),
#   ('que', 'sequor', 'contineo'),
#   ('sequor', 'contineo', 'alfonsus'),
#   ('contineo', 'alfonsus', 'filius'),
#   ('alfonsus', 'filius', 'rex'),
#   ('filius', 'rex', 'franci'),
#   ('rex', 'franci', 'comes'),
#   ('franci', 'comes', 'pictauensis'),
#   ('comes', 'pictauensis', 'tholose'),
#   ('pictauensis', 'tholose', 'uniuersus'),
#   ('tholose', 'uniuersus', 'preso'),
#   ('uniuersus', 'preso', 'littera'),
#   ('preso', 'littera', 'inspicio'),
#   ('littera', 'inspicio', 'salus'),
#   ('inspicio', 'salus', 'dominus')],
#  [('tanto', 'libence', 'petencius'),
#   ('libence', 'petencius', 'supplicatio'),
#   ('petencius', 'supplicatio', 'inclino'),
#   ('supplicatio', 'inclino', 'quanto1'),
#   ('inclino', 'quanto1', 'perpendo'),
#   ('quanto1', 'perpendo', 'hic1'),
#   ('perpendo', 'hic1', 'qui1'),
#   ('hic1', 'qui1', 'peto'),
#   ('qui1', 'peto', 'utilitas'),
#   ('peto', 'utilitas', 'ecclesiasticus'),
#   ('utilitas', 'ecclesiasticus', 'amplio')],
#  [('notus2', 'itaque', 'facio'),
#   ('itaque', 'facio', 'uenerabilis'),
#   ('facio', 'uenerabilis', 'uir'),
#   ('uenerabilis', 'uir', 'decanus'),
#   ('uir', 'decanus', 'capitulum'),
#   ('decanus', 'capitulum', 'ecclesie'),
#   ('capitulum', 'ecclesie', 'beatus'),
#   ('ecclesie', 'beatus', 'hilaris'),
#   ('beatus', 'hilaris', 'pictauensis'),
#   ('hilaris', 'pictauensis', 'prex'),
#   ('pictauensis', 'prex', 'inclinatus2'),
#   ('prex', 'inclinatus2', 'salus'),
#   ('inclinatus2', 'salus', 'animus'),
#   ('salus', 'animus', 'noster'),
#   ('animus', 'noster', 'deuocio'),
#   ('noster', 'deuocio', 'precipuus'),
#   ('deuocio', 'precipuus', 'habeo'),
#   ('precipuus', 'habeo', 'ecclesia'),
#   ('habeo', 'ecclesia', 'memoro'),
#   ('ecclesia', 'memoro', 'idem'),
#   ('memoro', 'idem', 'decanus'),
#   ('idem', 'decanus', 'capitulum'),
#   ('decanus', 'capitulum', 'homo'),
#   ('capitulum', 'homo', 'campigniacus'),
#   ('homo', 'campigniacus', 'nomen'),
#   ('campigniacus', 'nomen', 'idem'),
#   ('nomen', 'idem', 'ecclesie'),
#   ('idem', 'ecclesie', 'libere'),
#   ('ecclesie', 'libere', 'concedo1'),
#   ('libere', 'concedo1', 'liberalifer'),
#   ('concedo1', 'liberalifer', 'indulgeo'),
#   ('liberalifer', 'indulgeo', 'nos'),
#   ('indulgeo', 'nos', 'heres'),
#   ('nos', 'heres', 'successor'),
#   ('heres', 'successor', 'uilla'),
#   ('successor', 'uilla', 'campigniacus'),
#   ('uilla', 'campigniacus', 'exerceo'),
#   ('campigniacus', 'exerceo', 'mercor'),
#   ('exerceo', 'mercor', 'dies'),
#   ('mercor', 'dies', 'sabbatum'),
#   ('dies', 'sabbatum', 'quilibet'),
#   ('sabbatum', 'quilibet', 'ebdoma'),
#   ('quilibet', 'ebdoma', 'sum1'),
#   ('ebdoma', 'sum1', 'eo1'),
#   ('sum1', 'eo1', 'dico2'),
#   ('eo1', 'dico2', 'mercor'),
#   ('dico2', 'mercor', 'seu1'),
#   ('mercor', 'seu1', 'redeo1'),
#   ('seu1', 'redeo1', 'eodem'),
#   ('redeo1', 'eodem', 'ibidem'),
#   ('eodem', 'ibidem', 'commoror1'),
#   ('ibidem', 'commoror1', 'solucio'),
#   ('commoror1', 'solucio', 'nouus'),
#   ('solucio', 'nouus', 'pedagius'),
#   ('nouus', 'pedagius', 'seu1'),
#   ('pedagius', 'seu1', 'alter'),
#   ('seu1', 'alter', 'exactio'),
#   ('alter', 'exactio', 'indebite'),
#   ('exactio', 'indebite', 'parum2'),
#   ('indebite', 'parum2', 'compello1'),
#   ('parum2', 'compello1', 'alius'),
#   ('compello1', 'alius', 'debeo'),
#   ('alius', 'debeo', 'consuesco'),
#   ('debeo', 'consuesco', 'seruicium'),
#   ('consuesco', 'seruicium', 'seu1'),
#   ('seruicium', 'seu1', 'redeuancia'),
#   ('seu1', 'redeuancia', 'que'),
#   ('redeuancia', 'que', 'alibi'),
#   ('que', 'alibi', 'locus'),
#   ('alibi', 'locus', 'mercor'),
#   ('locus', 'mercor', 'exerceo'),
#   ('mercor', 'exerceo', 'presto'),
#   ('exerceo', 'presto', 'consuesco'),
#   ('presto', 'consuesco', 'exerceo'),
#   ('consuesco', 'exerceo', 'dictum'),
#   ('exerceo', 'dictum', 'mercor'),
#   ('dictum', 'mercor', 'soluo'),
#   ('mercor', 'soluo', 'teneo')],
#  [('qui1', 'res', 'testimonium'),
#   ('res', 'testimonium', 'preso'),
#   ('testimonium', 'preso', 'littera'),
#   ('preso', 'littera', 'sigillum'),
#   ('littera', 'sigillum', 'facio'),
#   ('sigillum', 'facio', 'impressio'),
#   ('facio', 'impressio', 'munio2')],
#  ...]

# %%
pdv_trigrams = []

for i in list(pdv_lemma.values()):
    pdv_trigrams.append(create_trigrams(i))

# %%
for value in tqdm(pdv_trigrams):
    
    comparaison_trigrams(value)
# Out:
# 100%|███████████████████████████████████████| 2048/2048 [02:12<00:00, 15.45it/s]

# %%
sum(livre_1.values())
# Out:
# 6330

# %%
un =  substitute_keys(matches_trigrams,pdv_lemma)
deux = transform_sentences_to_keys(un,guerin_lemma)
deux = remove_duplicates_from_dict_values(deux)

# %%
count_trigrams = {}

for key, value in deux.items():
    count_trigrams[key] = len(value)

# %%
count_sentences_trigrams = {}
#nombre de phrases qui ont au moins un bigramme similaire avec une phrase de guérin. 

for i in tqdm(range(363)):
    filtered_dict = {key: value for key, value in count_trigrams.items() if key.startswith(f"pdv_{i+1}_")}
    count_sentences_trigrams[f'pdv_{i+1}'] = sum(filtered_dict.values())
# Out:
# 100%|██████████████████████████████████████| 363/363 [00:00<00:00, 31335.56it/s]

# %%
keys = list(count_sentences_trigrams.keys())
values = list(count_sentences_trigrams.values())

livre_1 = {}
livre_2 = {}
livre_3 = {}
livre_4 = {}
livre_5 = {}
livre_6 = {}

for i in range(len(keys)):
    if i < 33:
        livre_1[keys[i]] = values[i]
    if 32 < i < 92:
        livre_2[keys[i]] = values[i]
    if 91 < i < 179:
        livre_3[keys[i]] = values[i]
    if 178 < i < 195:
        livre_4[keys[i]] = values[i]
    if 194 < i < 331:
        livre_5[keys[i]] = values[i]
    if 330 < i < 364:
        livre_6[keys[i]] = values[i]

# %%
livre1 = pd.DataFrame(list(livre_1.items()), columns=['Key', 'Value'])
statistics1 = pd.DataFrame(livre1['Value'].describe())

livre2 = pd.DataFrame(list(livre_2.items()), columns=['Key', 'Value'])
statistics2 = pd.DataFrame(livre2['Value'].describe())

livre3 = pd.DataFrame(list(livre_3.items()), columns=['Key', 'Value'])
statistics3 = pd.DataFrame(livre3['Value'].describe())

livre4 = pd.DataFrame(list(livre_4.items()), columns=['Key', 'Value'])
statistics4 = pd.DataFrame(livre4['Value'].describe())

livre5 = pd.DataFrame(list(livre_5.items()), columns=['Key', 'Value'])
statistics5 = pd.DataFrame(livre5['Value'].describe())

livre6 = pd.DataFrame(list(livre_6.items()), columns=['Key', 'Value'])
statistics6 = pd.DataFrame(livre6['Value'].describe())

# %%
livre1_array = np.array(livre1['Value'].tolist())
livre2_array = np.array(livre2['Value'].tolist())
livre3_array = np.array(livre3['Value'].tolist())
livre4_array = np.array(livre4['Value'].tolist())
livre5_array = np.array(livre5['Value'].tolist())
livre6_array = np.array(livre6['Value'].tolist())
list_livre = [livre1_array,livre2_array,livre3_array,livre4_array,livre5_array,livre6_array]
list_livre[0]
# Out:
# array([ 0,  0, 20,  0,  3,  1,  0,  0,  0,  2,  0,  0,  0,  0,  0,  1,  7,
#         0,  0,  0,  7,  0,  0,  3,  0,  1,  9,  1,  1,  1,  0,  1,  0])

# %%
"""sns.set(style="whitegrid")
facecolor = '#eaeaf2'
fig, ax = plt.subplots(figsize=(12, 9), facecolor=facecolor)
sns.boxplot(data=list_livre, palette="Set3",showmeans=True,
            meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
#plt.yscale("log")
ax.set_ylabel('Nombres de correspondances de bigrams de mots dans les textes de Guérin', 
              fontsize=12)
custom_labels = ['livre 1','livre 2','livre 3','livre 4','livre 5','livre 6']
plt.xticks(range(len(custom_labels)), custom_labels)
plt.title('Nombre de phrases de Guérin dans lesquelles on retrouve au moins un bigram en commun avec Pierre de la Vigne')"""
# Out:
# 'sns.set(style="whitegrid")\nfacecolor = \'#eaeaf2\'\nfig, ax = plt.subplots(figsize=(12, 9), facecolor=facecolor)\nsns.boxplot(data=list_livre, palette="Set3",showmeans=True,\n            meanprops={"marker":"o",\n                       "markerfacecolor":"white", \n                       "markeredgecolor":"black",\n                      "markersize":"10"})\n#plt.yscale("log")\nax.set_ylabel(\'Nombres de correspondances de bigrams de mots dans les textes de Guérin\', \n              fontsize=12)\ncustom_labels = [\'livre 1\',\'livre 2\',\'livre 3\',\'livre 4\',\'livre 5\',\'livre 6\']\nplt.xticks(range(len(custom_labels)), custom_labels)\nplt.title(\'Nombre de phrases de Guérin dans lesquelles on retrouve au moins un bigram en commun avec Pierre de la Vigne\')'

# %%
liste_trigrams = [sum(livre_1.values()),sum(livre_2.values()),sum(livre_3.values()),
                     sum(livre_4.values()),sum(livre_5.values()),sum(livre_6.values())]

# %% [markdown]
# # Quadrigrams

# %%
x = create_quadrigrams(list(pdv_2.values())[0])

# %%
guerin_quadrigrams = []

for i in list(guerin_lemma.values()):
    guerin_quadrigrams.append(create_quadrigrams(i))

# %%
pdv_quadrigrams = []

for i in list(pdv_lemma.values()):
    pdv_quadrigrams.append(create_quadrigrams(i))

# %%
for value in tqdm(pdv_quadrigrams):
    
    comparaison_quadrigrams(value)
# Out:
# 100%|███████████████████████████████████████| 2048/2048 [02:01<00:00, 16.90it/s]

# %%
un =  substitute_keys(matches_quadrigrams,pdv_lemma)
deux = transform_sentences_to_keys(un,guerin_lemma)
deux = remove_duplicates_from_dict_values(deux)

# %%
count_quadrigrams = {}

for key, value in deux.items():
    count_quadrigrams[key] = len(value)

# %%
count_sentences_quadrigrams = {}
#nombre de phrases qui ont au moins un bigramme similaire avec une phrase de guérin. 

for i in tqdm(range(363)):
    filtered_dict = {key: value for key, value in count_quadrigrams.items() if key.startswith(f"pdv_{i+1}_")}
    count_sentences_quadrigrams[f'pdv_{i+1}'] = sum(filtered_dict.values())
# Out:
# 100%|█████████████████████████████████████| 363/363 [00:00<00:00, 140844.81it/s]

# %%
keys = list(count_sentences_quadrigrams.keys())
values = list(count_sentences_quadrigrams.values())

livre_1 = {}
livre_2 = {}
livre_3 = {}
livre_4 = {}
livre_5 = {}
livre_6 = {}

for i in range(len(keys)):
    if i < 33:
        livre_1[keys[i]] = values[i]
    if 32 < i < 92:
        livre_2[keys[i]] = values[i]
    if 91 < i < 179:
        livre_3[keys[i]] = values[i]
    if 178 < i < 195:
        livre_4[keys[i]] = values[i]
    if 194 < i < 331:
        livre_5[keys[i]] = values[i]
    if 330 < i < 364:
        livre_6[keys[i]] = values[i]

# %%
one = list(livre_1.values())
two = list(livre_2.values())
three = list(livre_3.values())
four = list(livre_4.values())
five = list(livre_5.values())
six = list(livre_5.values())
liste_livres = [one, two, three, four, five, six]

# %%
"""sns.set(style="whitegrid")
facecolor = '#eaeaf2'
fig, ax = plt.subplots(figsize=(12, 9), facecolor=facecolor)
sns.boxplot(data=liste_livres, palette="Set3",showmeans=True,
            meanprops={"marker":"o",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"10"})
plt.yscale("log")
ax.set_ylabel('Nombres de correspondances de bigrams de mots dans les textes de Guérin', 
              fontsize=12)
custom_labels = ['livre 1','livre 2','livre 3','livre 4','livre 5','livre 6']
plt.xticks(range(len(custom_labels)), custom_labels)
plt.title('Nombre de phrases de Guérin dans lesquelles on retrouve au moins un bigram en commun avec Pierre de la Vigne')"""
# Out:
# 'sns.set(style="whitegrid")\nfacecolor = \'#eaeaf2\'\nfig, ax = plt.subplots(figsize=(12, 9), facecolor=facecolor)\nsns.boxplot(data=liste_livres, palette="Set3",showmeans=True,\n            meanprops={"marker":"o",\n                       "markerfacecolor":"white", \n                       "markeredgecolor":"black",\n                      "markersize":"10"})\nplt.yscale("log")\nax.set_ylabel(\'Nombres de correspondances de bigrams de mots dans les textes de Guérin\', \n              fontsize=12)\ncustom_labels = [\'livre 1\',\'livre 2\',\'livre 3\',\'livre 4\',\'livre 5\',\'livre 6\']\nplt.xticks(range(len(custom_labels)), custom_labels)\nplt.title(\'Nombre de phrases de Guérin dans lesquelles on retrouve au moins un bigram en commun avec Pierre de la Vigne\')'

# %%
liste_quadrigrams = [sum(livre_1.values()),sum(livre_2.values()),sum(livre_3.values()),
                     sum(livre_4.values()),sum(livre_5.values()),sum(livre_6.values())]

# %%
liste_bigrams
# Out:
# [6330, 5862, 8332, 1224, 14920, 10271]

# %% [markdown]
# # Quintigrams

# %%
guerin_quintigrams = []

for i in list(guerin_lemma.values()):
    guerin_quintigrams.append(create_quintigrams(i))

# %%
pdv_quintigrams = []

for i in list(pdv_lemma.values()):
    pdv_quintigrams.append(create_quintigrams(i))

# %%
for value in tqdm(pdv_quintigrams):
    
    comparaison_quintigrams(value)
# Out:
# 100%|███████████████████████████████████████| 2048/2048 [01:54<00:00, 17.91it/s]

# %%
un =  substitute_keys(matches_quintigrams,pdv_lemma)
deux = transform_sentences_to_keys(un,guerin_lemma)
deux = remove_duplicates_from_dict_values(deux)

# %%
count_quintigrams = {}

for key, value in deux.items():
    count_quintigrams[key] = len(value)

# %%
count_sentences_quintigrams = {}
#nombre de phrases qui ont au moins un bigramme similaire avec une phrase de guérin. 

for i in tqdm(range(363)):
    filtered_dict = {key: value for key, value in count_quintigrams.items() if key.startswith(f"pdv_{i+1}_")}
    count_sentences_quintigrams[f'pdv_{i+1}'] = sum(filtered_dict.values())
# Out:
# 100%|█████████████████████████████████████| 363/363 [00:00<00:00, 569383.83it/s]

# %%
keys = list(count_sentences_quintigrams.keys())
values = list(count_sentences_quintigrams.values())

livre_1 = {}
livre_2 = {}
livre_3 = {}
livre_4 = {}
livre_5 = {}
livre_6 = {}

for i in range(len(keys)):
    if i < 33:
        livre_1[keys[i]] = values[i]
    if 32 < i < 92:
        livre_2[keys[i]] = values[i]
    if 91 < i < 179:
        livre_3[keys[i]] = values[i]
    if 178 < i < 195:
        livre_4[keys[i]] = values[i]
    if 194 < i < 331:
        livre_5[keys[i]] = values[i]
    if 330 < i < 364:
        livre_6[keys[i]] = values[i]

# %%
one = list(livre_1.values())
two = list(livre_2.values())
three = list(livre_3.values())
four = list(livre_4.values())
five = list(livre_5.values())
six = list(livre_5.values())
liste_livres = [one, two, three, four, five, six]
liste_quintigrams = [sum(livre_1.values()),sum(livre_2.values()),sum(livre_3.values()),
                     sum(livre_4.values()),sum(livre_5.values()),sum(livre_6.values())]

# %%
data = [liste_bigrams,liste_trigrams,liste_quadrigrams,liste_quintigrams]

columns = ('livre 1', 'livre 2', 'livre 3', 'livre 4', 'livre 5', 'livre 6')

# %%
data
# Out:
# [[6330, 5862, 8332, 1224, 14920, 10271],
#  [58, 67, 85, 5, 242, 2110],
#  [0, 4, 6, 0, 21, 1130],
#  [0, 0, 0, 0, 0, 514]]

# %%
data = [liste_bigrams,liste_trigrams,liste_quadrigrams,liste_quintigrams]

columns = ('livre 1', 'livre 2', 'livre 3', 'livre 4', 'livre 5', 'livre 6')

sns.set(style="whitegrid")
facecolor = '#eaeaf2'
data = data

columns = ('livre 1', 'livre 2', 'livre 3', 'livre 4', 'livre 5', 'livre 6')
rows = [x for x in ('quinti-grams', 'quadri-grams', 'tri-grams', 'bi-grams')
]

plt.figure(figsize=(15,9))

values = np.arange(0, 10001, 2000)
value_increment = 2000

# Get some pastel shades for the colors
colors = plt.cm.tab20c(np.linspace(0, 1, len(rows)))
n_rows = len(data)

index = np.arange(len(columns)) + 0.3
bar_width = 0.4

# Initialize the vertical-offset for the stacked bar chart.
y_offset = np.zeros(len(columns))

# Plot bars and create text labels for the table
cell_text = []
for row in range(n_rows):
    plt.bar(index, data[row], bar_width, bottom=y_offset, color=colors[row])
    y_offset = y_offset + data[row]
    cell_text.append(['%d' % x for x in data[row]])

# Reverse colors and text labels to display the last value at the top.
colors = colors[::-1]
cell_text.reverse()

# Add a table at the bottom of the axes
the_table = plt.table(cellText=cell_text,
                      rowLabels=rows,
                      rowColours=colors,
                      colLabels=columns,
                      loc='bottom')

# Adjust layout to make room for the table:
plt.subplots_adjust(left=0.2, bottom=0.2)

plt.ylabel(f"Loss in ${value_increment}'s")

plt.yticks(values, ['%d' % val for val in values])
plt.xticks([])
plt.title('A')


plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_531466/1159853693.py in <module>
#      29 cell_text = []
#      30 for row in range(n_rows):
# ---> 31     plt.bar(index, data[row], bar_width, bottom=y_offset, color=colors[row])
#      32     y_offset = y_offset + data[row]
#      33     cell_text.append(['%d' % x for x in data[row]])
#
# ~/python/miniconda/envs/coursnlp/lib/python3.7/site-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2397     return gca().bar(
#    2398         x, height, width=width, bottom=bottom, align=align,
# -> 2399         **({"data": data} if data is not None else {}), **kwargs)
#    2400
#    2401
#
# ~/python/miniconda/envs/coursnlp/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1412     def inner(ax, *args, data=None, **kwargs):
#    1413         if data is None:
# -> 1414             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1415
#    1416         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/python/miniconda/envs/coursnlp/lib/python3.7/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2345         x, height, width, y, linewidth, hatch = np.broadcast_arrays(
#    2346             # Make args iterable too.
# -> 2347             np.atleast_1d(x), height, width, y, linewidth, hatch)
#    2348
#    2349         # Now that units have been converted, set the tick locations.
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# ~/python/miniconda/envs/coursnlp/lib/python3.7/site-packages/numpy/lib/stride_tricks.py in broadcast_arrays(subok, *args)
#     536     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     537
# --> 538     shape = _broadcast_shape(*args)
#     539
#     540     if all(array.shape == shape for array in args):
#
# ~/python/miniconda/envs/coursnlp/lib/python3.7/site-packages/numpy/lib/stride_tricks.py in _broadcast_shape(*args)
#     418     # use the old-iterator because np.nditer does not handle size 0 arrays
#     419     # consistently
# --> 420     b = np.broadcast(*args[:32])
#     421     # unfortunately, it cannot handle 32 or more arguments directly
#     422     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape
